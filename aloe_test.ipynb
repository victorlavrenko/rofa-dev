# %%
import torch
print("torch:", torch.__version__)
print("cuda available:", torch.cuda.is_available())
print("torch cuda version:", torch.version.cuda)
# Out:
# torch: 2.9.0+cu126
# cuda available: True
# torch cuda version: 12.6

# %%
# %pip install -q flash-attn --no-build-isolation
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 79.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for flash-attn (setup.py) ... done

# %%
import re
import torch
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM

MODEL_ID = "HPAI-BSC/Llama3.1-Aloe-Beta-8B"

SYSTEM = (
    "You are an expert medical assistant named Aloe, developed by the High Performance "
    "Artificial Intelligence Group at Barcelona Supercomputing Center(BSC). "
    "You are to be a helpful, respectful, and honest assistant."
)

def build_user(q):
    return (
        "For the following multiple-choice question, select one correct answer. "
        "Let's think step by step. "
        f"Question: {q['question']} "
        f"Options: A. {q['opa']} B. {q['opb']} C. {q['opc']} D. {q['opd']}"
    )

import re
from dataclasses import dataclass
from typing import Optional, Dict, Tuple

# Precompiled regexes
_STRONG_PATTERNS = [
    re.compile(r"(?:^|\n)\s*(?:final\s+answer|answer)\s*[:\-–]\s*([ABCD])\b", re.I),
    re.compile(r"\b(?:so,?\s*)?(?:the\s+)?answer\s+is\s*([ABCD])\b", re.I),
    re.compile(r"\b(?:correct\s+answer|correct\s+option)\s*(?:is|:)\s*([ABCD])\b", re.I),
    re.compile(r"\boption\s*([ABCD])\b\s*(?:is\s*)?(?:correct|best|most\s+likely|most\s+accurate)\b", re.I),
]

_KEYWORD_RX = re.compile(r"\b(answer|final|correct|best|therefore|so)\b", re.I)
_END_LETTER_RX = re.compile(r"\b([ABCD])\b\s*[\.\!\?]?\s*$", re.I)
_PAREN_LETTER_RX = re.compile(r"[\(\[]\s*([ABCD])\s*[\)\]]", re.I)
_ENUM_LINE_RX = re.compile(r"^\s*([ABCD])\s*[\.\)]\s", re.I)
_WEAK_TAIL_RX = re.compile(r"(?:^|[\s\(\[\{])([ABCD])(?:[\]\}\)\s\.\!\?]|$)", re.I)

@dataclass(frozen=True)
class ExtractDebug:
    method: str
    scores: Dict[str, int]

def _extract_impl(text: str, *, return_debug: bool = False) -> Tuple[Optional[str], Optional[ExtractDebug]]:
    if not text:
        dbg = ExtractDebug(method="empty", scores={}) if return_debug else None
        return None, dbg

    t = text.strip()

    # 1) Strong patterns: take the last match across all patterns
    last: Optional[Tuple[int, str, int]] = None  # (pos, letter, pattern_idx)
    for idx, rx in enumerate(_STRONG_PATTERNS):
        for m in rx.finditer(t):
            last = (m.start(1), m.group(1).upper(), idx)

    if last is not None:
        letter = last[1]
        dbg = ExtractDebug(method=f"strong[{last[2]}]", scores={letter: 999}) if return_debug else None
        return letter, dbg

    # 2) Tail scoring
    tail = t[-800:]
    scores: Dict[str, int] = {k: 0 for k in "ABCD"}

    for m in _KEYWORD_RX.finditer(tail):
        window = tail[m.start(): m.start() + 120]
        for L in "ABCD":
            if re.search(rf"\b{L}\b", window, re.I):
                scores[L] += 5

    m_end = _END_LETTER_RX.search(tail)
    if m_end:
        scores[m_end.group(1).upper()] += 6

    for m in _PAREN_LETTER_RX.finditer(tail):
        scores[m.group(1).upper()] += 2

    enum_counts = {k: 0 for k in "ABCD"}
    for line in tail.splitlines():
        mm = _ENUM_LINE_RX.match(line)
        if mm:
            enum_counts[mm.group(1).upper()] += 1

    if sum(enum_counts.values()) >= 2:
        for L in "ABCD":
            scores[L] -= min(2, enum_counts[L])

    best_letter, best_score = max(scores.items(), key=lambda kv: kv[1])
    if best_score >= 4:
        dbg = ExtractDebug(method="tail-score", scores=scores) if return_debug else None
        return best_letter, dbg

    # 3) Last resort: last isolated letter token in tail, avoiding enumeration headers
    last_letter: Optional[str] = None
    for m in _WEAK_TAIL_RX.finditer(tail):
        L = m.group(1).upper()
        suffix = tail[m.start(): m.start() + 4]
        if _ENUM_LINE_RX.match(suffix):
            continue
        last_letter = L

    dbg = ExtractDebug(method="weak-tail", scores=scores) if return_debug else None
    return last_letter, dbg

def extract_choice_letter(text: str) -> Optional[str]:
    letter, _ = _extract_impl(text, return_debug=False)
    return letter

def extract_choice_letter_debug(text: str) -> Tuple[Optional[str], Dict[str, int], str]:
    letter, dbg = _extract_impl(text, return_debug=True)
    if dbg is None:
        return letter, {}, "unknown"
    return letter, dbg.scores, dbg.method

def cop_to_letter(cop: int):
    # cop = 0..3
    return "ABCD"[int(cop)]

ds = load_dataset("openlifescienceai/medmcqa", split="validation")
ds = ds.filter(
    lambda x: (
        x.get("choice_type") == "single"
        and isinstance(x.get("exp"), str)
        and len(x["exp"]) > 20
        and len(x["exp"]) < 500
    )
)

tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)

def load_model(attn_impl: str):
    return AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        dtype=torch.bfloat16,
        device_map={"": "cuda:0"},
        attn_implementation=attn_impl,   # "flash_attention_2" или "sdpa"
    ).eval()

# пробуем flash_attention_2, если не выйдет — sdpa
try:
    model = load_model("flash_attention_2")
    print("Using FlashAttention2")
except Exception as e:
    print("FlashAttention2 failed, falling back to SDPA:", repr(e))
    model = load_model("sdpa")
    print("Using SDPA")

print("attn_implementation in config:", getattr(model.config, "_attn_implementation", None))

def get_eos_ids(tokenizer):
    eos_ids = [tokenizer.eos_token_id]
    try:
        eot = tokenizer.convert_tokens_to_ids("<|eot_id|>")
        if isinstance(eot, int) and eot >= 0:
            eos_ids.append(eot)
    except Exception:
        pass
    # уникальные, без None
    return list({i for i in eos_ids if isinstance(i, int)})

eos_ids = get_eos_ids(tokenizer)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/85.9M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/936k [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/1.48M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/182822 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/6150 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/4183 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/4183 [00:00<?, ? examples/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Using FlashAttention2
# attn_implementation in config: flash_attention_2

# %%
import time

def infer_one(
    example,
    max_new_tokens: int = 512,
    *,
    # New (branching) knobs — optional, preserve old behavior by default
    seed: int | None = None,
    temperature: float | None = None,
    do_sample: bool | None = None,
    top_p: float = 1.0,
    top_k: int = 0,
):
    """
    Backward-compatible:
      - If you call infer_one(example) or infer_one(example, max_new_tokens=...),
        it behaves exactly like the old version: greedy (do_sample=False), deterministic.
    Branching mode:
      - Pass do_sample=True and (optionally) temperature and seed.
      - If do_sample=True and temperature is None -> uses 1.0.
      - If seed is provided, seeds torch + cuda + python RNG for better reproducibility.
    """

    # ---- optional seeding (only if seed is provided) ----
    if seed is not None:
        import os, random
        os.environ["PYTHONHASHSEED"] = str(seed)
        random.seed(seed)
        torch.manual_seed(seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(seed)

    # ---- preserve legacy defaults ----
    if do_sample is None:
        do_sample = False  # old behavior

    if temperature is None:
        temperature = 1.0  # harmless for greedy; used for sampling

    messages = [
        {"role": "system", "content": SYSTEM},
        {"role": "user", "content": build_user(example)},
    ]

    prompt = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t0 = time.time()

    gen_kwargs = dict(
        **inputs,
        max_new_tokens=max_new_tokens,
        do_sample=do_sample,
        num_beams=1,
        use_cache=True,
    )

    # Only add sampling params when sampling is enabled (keeps old mode identical)
    if do_sample:
        gen_kwargs.update(
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
        )

    with torch.no_grad():
        out = model.generate(**gen_kwargs)

    if torch.cuda.is_available():
        torch.cuda.synchronize()
    t1 = time.time()

    gen = tokenizer.decode(
        out[0][inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True
    )
    pred = extract_choice_letter(gen)
    gold = cop_to_letter(example["cop"])
    return pred, gold, gen, t1 - t0

# %%
import torch

if torch.cuda.is_available():
    props = torch.cuda.get_device_properties(0)
    total_gb = props.total_memory / 1024**3
    allocated_gb = torch.cuda.memory_allocated(0) / 1024**3
    reserved_gb = torch.cuda.memory_reserved(0) / 1024**3

    print(f"GPU: {props.name}")
    print(f"Total VRAM: {total_gb:.2f} GB")
    print(f"Allocated:  {allocated_gb:.2f} GB")
    print(f"Reserved:   {reserved_gb:.2f} GB")
else:
    print("CUDA not available")
# Out:
# GPU: NVIDIA A100-SXM4-40GB
# Total VRAM: 39.56 GB
# Allocated:  14.96 GB
# Reserved:   14.96 GB

# %%
import json
from datetime import datetime, timezone
from collections import Counter

SEED = 42
MAX_NEW_TOKENS = 1024
N = 100

SUBJECTS = 20
MAX_PER_SUBJECT = N / SUBJECTS * 1.1 + 1

LOGFILE = f"medmcqa_run_aloe_8b_N{N}_seed{SEED}_maxnew{MAX_NEW_TOKENS}.json"

logs = []
shuffled = ds.shuffle(seed=SEED)

# %%
subject_counts = Counter()
i = 0        # индекс по shuffled
picked = 0   # сколько реально набрали

print("Starting inference loop...")

while picked < N and i < len(shuffled):
    ex = shuffled[i]
    subj = ex.get("subject_name", "Unknown") or "Unknown"

    if subject_counts[subj] >= MAX_PER_SUBJECT:
        i += 1
        continue

    subject_counts[subj] += 1
    picked += 1

    pred, gold, gen, inference_time = infer_one(ex, max_new_tokens=MAX_NEW_TOKENS)

    record = {
        "index": i,
        "id": ex.get("id"),
        "question": ex.get("question"),
        "options": {
            "A": ex.get("opa"),
            "B": ex.get("opb"),
            "C": ex.get("opc"),
            "D": ex.get("opd"),
        },
        "gold": gold,
        "prediction": pred,
        "is_correct": (pred == gold) if pred is not None else None,
        "model_output": gen,
        "subject_name": subj,
        "inference_time_sec": inference_time,
        "model": MODEL_ID,
        "max_new_tokens": MAX_NEW_TOKENS,
        "seed": SEED,
        "timestamp": datetime.now(timezone.utc).isoformat(),
    }

    logs.append(record)

    if pred is None:
        print("  Warning: could not extract answer from model output.")
        picked -= 1  # не засчитываем этот пример

    i += 1

    # краткий консольный лог
    print(f"{i-1, picked-1} pred={pred} gold={gold} correct={record['is_correct']}, subject={subj}")

print("Inference loop completed.")
with open(LOGFILE, "w", encoding="utf-8") as f:
    json.dump(logs, f, ensure_ascii=False, indent=2)
# Out:
# Starting inference loop...
# (0, 0) pred=D gold=D correct=True, subject=Pediatrics
# (1, 1) pred=A gold=A correct=True, subject=Ophthalmology
# (2, 2) pred=A gold=D correct=False, subject=Pharmacology
# (3, 3) pred=B gold=B correct=True, subject=Microbiology
# (4, 4) pred=D gold=D correct=True, subject=Pharmacology
# (5, 5) pred=B gold=D correct=False, subject=Pathology
# (6, 6) pred=A gold=A correct=True, subject=Anatomy
# (7, 7) pred=A gold=B correct=False, subject=Surgery
# (8, 8) pred=B gold=C correct=False, subject=Social & Preventive Medicine
# (9, 9) pred=D gold=B correct=False, subject=Dental
# (10, 10) pred=B gold=B correct=True, subject=Dental
# (11, 11) pred=B gold=A correct=False, subject=Anatomy
# (12, 12) pred=B gold=B correct=True, subject=Biochemistry
# (13, 13) pred=D gold=D correct=True, subject=Gynaecology & Obstetrics
# (14, 14) pred=A gold=A correct=True, subject=Radiology
# (15, 15) pred=A gold=B correct=False, subject=Pediatrics
# (16, 16) pred=C gold=C correct=True, subject=Physiology
# (17, 17) pred=A gold=B correct=False, subject=Dental
# (18, 18) pred=A gold=A correct=True, subject=Medicine
# (19, 19) pred=A gold=C correct=False, subject=Gynaecology & Obstetrics
# (20, 20) pred=A gold=A correct=True, subject=Pharmacology
# (21, 21) pred=B gold=C correct=False, subject=ENT
# (22, 22) pred=D gold=D correct=True, subject=Pathology
# (23, 23) pred=C gold=B correct=False, subject=Pathology
# (24, 24) pred=A gold=D correct=False, subject=Pathology
# (25, 25) pred=A gold=A correct=True, subject=Orthopaedics
# (26, 26) pred=D gold=A correct=False, subject=Radiology
# (27, 27) pred=B gold=B correct=True, subject=Surgery
# (28, 28) pred=D gold=D correct=True, subject=Dental
# (29, 29) pred=B gold=B correct=True, subject=Social & Preventive Medicine
# (30, 30) pred=B gold=B correct=True, subject=Surgery
# (31, 31) pred=A gold=C correct=False, subject=Dental
# (32, 32) pred=D gold=B correct=False, subject=Medicine
# (33, 33) pred=B gold=B correct=True, subject=Pediatrics
# (34, 34) pred=C gold=C correct=True, subject=Social & Preventive Medicine
# (35, 35) pred=B gold=B correct=True, subject=Ophthalmology
# (36, 36) pred=A gold=B correct=False, subject=Gynaecology & Obstetrics
# (37, 37) pred=C gold=C correct=True, subject=Gynaecology & Obstetrics
# (38, 38) pred=A gold=A correct=True, subject=Anatomy
# (39, 39) pred=B gold=B correct=True, subject=Anatomy
# (40, 40) pred=B gold=B correct=True, subject=Gynaecology & Obstetrics
# (41, 41) pred=B gold=D correct=False, subject=Anatomy
# (42, 42) pred=B gold=B correct=True, subject=Surgery
# (43, 43) pred=D gold=D correct=True, subject=Medicine
# (44, 44) pred=C gold=C correct=True, subject=Pharmacology
# (45, 45) pred=A gold=A correct=True, subject=Physiology
# (46, 46) pred=A gold=A correct=True, subject=Surgery
# (47, 47) pred=D gold=D correct=True, subject=Medicine
# (48, 48) pred=D gold=A correct=False, subject=Surgery
# (49, 49) pred=D gold=B correct=False, subject=Gynaecology & Obstetrics
# (50, 50) pred=C gold=C correct=True, subject=Anatomy
# (51, 51) pred=D gold=B correct=False, subject=Pharmacology
# (52, 52) pred=D gold=D correct=True, subject=Anatomy
# (53, 53) pred=A gold=A correct=True, subject=Pathology
# (54, 54) pred=C gold=C correct=True, subject=Gynaecology & Obstetrics
# (55, 55) pred=A gold=A correct=True, subject=Forensic Medicine
# (56, 56) pred=B gold=C correct=False, subject=Surgery
# (58, 57) pred=A gold=A correct=True, subject=Biochemistry
# (62, 58) pred=D gold=D correct=True, subject=Pathology
# (63, 59) pred=A gold=A correct=True, subject=Pharmacology
# (64, 60) pred=C gold=C correct=True, subject=Pharmacology
# (65, 61) pred=D gold=D correct=True, subject=Pediatrics
# (66, 62) pred=A gold=A correct=True, subject=Microbiology
# (69, 63) pred=B gold=B correct=True, subject=ENT
# (71, 64) pred=D gold=D correct=True, subject=Dental
# (72, 65) pred=A gold=B correct=False, subject=Forensic Medicine
# (75, 66) pred=A gold=A correct=True, subject=Microbiology
# (77, 67) pred=D gold=D correct=True, subject=Medicine
# (78, 68) pred=A gold=A correct=True, subject=Medicine
# (79, 69) pred=D gold=D correct=True, subject=Medicine
# (80, 70) pred=D gold=D correct=True, subject=Pathology
# (81, 71) pred=B gold=B correct=True, subject=Dental
# (83, 72) pred=A gold=C correct=False, subject=Social & Preventive Medicine
# (84, 73) pred=B gold=B correct=True, subject=Biochemistry
# (85, 74) pred=A gold=A correct=True, subject=Biochemistry
# (86, 75) pred=D gold=B correct=False, subject=Social & Preventive Medicine
# (88, 76) pred=A gold=A correct=True, subject=Social & Preventive Medicine
# (89, 77) pred=B gold=B correct=True, subject=Forensic Medicine
# (94, 78) pred=C gold=A correct=False, subject=Anaesthesia
# (95, 79) pred=D gold=D correct=True, subject=Biochemistry
# (98, 80) pred=B gold=B correct=True, subject=Social & Preventive Medicine
# (99, 81) pred=B gold=B correct=True, subject=Physiology
# (102, 82) pred=A gold=C correct=False, subject=Physiology
# (103, 83) pred=A gold=A correct=True, subject=Physiology
# (105, 84) pred=A gold=A correct=True, subject=Radiology
# (109, 85) pred=B gold=B correct=True, subject=Pediatrics
# (111, 86) pred=A gold=A correct=True, subject=Pediatrics
# (115, 87) pred=C gold=D correct=False, subject=Microbiology
# (123, 88) pred=A gold=A correct=True, subject=Forensic Medicine
# (131, 89) pred=D gold=B correct=False, subject=Microbiology
# (133, 90) pred=D gold=D correct=True, subject=Ophthalmology
# (136, 91) pred=B gold=A correct=False, subject=Forensic Medicine
# (139, 92) pred=D gold=D correct=True, subject=Microbiology
# (140, 93) pred=D gold=B correct=False, subject=Anaesthesia
# (149, 94) pred=A gold=A correct=True, subject=ENT
# (151, 95) pred=A gold=D correct=False, subject=Ophthalmology
# (154, 96) pred=B gold=B correct=True, subject=Pediatrics
# (157, 97) pred=D gold=D correct=True, subject=Skin
# (165, 98) pred=A gold=D correct=False, subject=Biochemistry
# (171, 99) pred=A gold=A correct=True, subject=Microbiology
# Inference loop completed.

# %%
import os
import json
import time
import math
from datetime import datetime, timezone
from collections import Counter

# ----------------------------
# Config (align with your run)
# ----------------------------

# Branching
N_BRANCHES = 10
BASE_SEED = SEED

BRANCH_TEMPERATURE = 0.8
BRANCH_TOP_P = 0.8
BRANCH_TOP_K = 50

# Files (JSONL for safe incremental append)
FULL_LOGFILE = f"medmcqa_branches_full_N{N}_seed{SEED}_maxnew{MAX_NEW_TOKENS}_b{N_BRANCHES}_t{BRANCH_TEMPERATURE}.jsonl"
BRANCHES_SUMMARY_LOGFILE = f"medmcqa_branches_summary_N{N}_seed{SEED}_maxnew{MAX_NEW_TOKENS}_b{N_BRANCHES}_t{BRANCH_TEMPERATURE}.jsonl"

# ----------------------------
# Helpers
# ----------------------------
def _now_utc():
    return datetime.now(timezone.utc).isoformat()

def _append_jsonl(path: str, obj: dict):
    # Atomic-ish append per record; ensures we don't lose everything on crash
    with open(path, "a", encoding="utf-8") as f:
        f.write(json.dumps(obj, ensure_ascii=False) + "\n")
        f.flush()

def _safe_counter_preds(preds):
    # count only valid letters
    letters = [p for p in preds if p in ("A", "B", "C", "D")]
    return Counter(letters), len(letters)

def _entropy_from_counter(cnt: Counter, total: int) -> float:
    if total <= 0:
        return 0.0
    ent = 0.0
    for k, v in cnt.items():
        p = v / total
        ent -= p * math.log(p + 1e-12, 2)
    return ent

def _diversity_metrics(preds):
    """
    Returns:
      - leader: most common answer among A/B/C/D (or None)
      - max_frac: leader share among valid preds
      - variation_ratio: 1 - max_frac (0 means unanimous among valid preds)
      - entropy_bits: Shannon entropy (0..2 for 4-way)
      - valid_n: how many branches produced A/B/C/D
      - none_n: how many are None/invalid
      - unanimous: all *valid* preds identical AND valid_n == N_BRANCHES
      - unanim_valid: all valid preds identical (ignores missing)
    """
    cnt, valid_n = _safe_counter_preds(preds)
    none_n = len(preds) - valid_n

    if valid_n == 0:
        return {
            "leader": None,
            "max_frac": 0.0,
            "variation_ratio": 0.0,
            "entropy_bits": 0.0,
            "valid_n": 0,
            "none_n": none_n,
            "unanimous": False,
            "unanim_valid": False,
        }

    leader, leader_count = cnt.most_common(1)[0]
    max_frac = leader_count / valid_n
    variation_ratio = 1.0 - max_frac
    entropy_bits = _entropy_from_counter(cnt, valid_n)

    unanim_valid = (len(cnt) == 1)
    unanimous = (unanim_valid and valid_n == len(preds))  # all 10 produced the same letter

    return {
        "leader": leader,
        "max_frac": max_frac,
        "variation_ratio": variation_ratio,
        "entropy_bits": entropy_bits,
        "valid_n": valid_n,
        "none_n": none_n,
        "unanimous": unanimous,
        "unanim_valid": unanim_valid,
    }

def _correct_fraction(preds, gold):
    valid = [p for p in preds if p in ("A", "B", "C", "D")]
    if not valid:
        return 0.0
    return sum(1 for p in valid if p == gold) / len(valid)

# ----------------------------
# Dataset shuffle + subject cap
# ----------------------------
logs_full_count = 0
logs_summary_count = 0

# Start fresh files (optional): comment out if you want to append to existing
open(FULL_LOGFILE, "w", encoding="utf-8").close()
open(BRANCHES_SUMMARY_LOGFILE, "w", encoding="utf-8").close()

subject_counts = Counter()

i = 0        # index over shuffled
picked = 0   # accepted examples

# ----------------------------
# Aggregation buckets (final report)
# ----------------------------
bucket_counts = Counter()
# keys we will use:
# unanimous_correct, unanimous_wrong,
# lead80_correct, lead80_wrong,
# lead50_correct, lead50_wrong,
# no_leader, invalid_all_none

print("Starting branching inference loop...")
t_global0 = time.time()

while picked < N and i < len(shuffled):
    print(f"Processing example index {i} (picked {picked}/{N})...")
    ex = shuffled[i]
    subj = ex.get("subject_name", "Unknown") or "Unknown"

    if subject_counts[subj] >= MAX_PER_SUBJECT:
        i += 1
        continue

    gold = cop_to_letter(ex["cop"])
    question_id = ex.get("id")
    print(f" Gold: {gold}, Subject: {subj}, Question ID: {question_id}")

    # Reserve subject slot and count this example as picked
    subject_counts[subj] += 1
    picked += 1

    # --- run branches ---
    preds = []
    branch_times = []
    branch_records = []

    t0 = time.time()

    # Make seeds differ per example AND per branch to reduce correlations
    example_seed_offset = 100_000 * picked

    for j in range(N_BRANCHES):
        seed = BASE_SEED + example_seed_offset + 10_000 + j * 997

        pred, _, gen, dt = infer_one(
            ex,
            seed=seed,
            temperature=BRANCH_TEMPERATURE,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=True,
            top_p=BRANCH_TOP_P,
            top_k=BRANCH_TOP_K,
        )

        preds.append(pred)
        branch_times.append(dt)

        branch_records.append({
            "branch": j,
            "seed": seed,
            "temperature": BRANCH_TEMPERATURE,
            "top_p": BRANCH_TOP_P,
            "top_k": BRANCH_TOP_K,
            "pred": pred,
            "gold": gold,
            "is_correct": (pred == gold) if pred is not None else None,
            "inference_time_sec": dt,
            "model_output": gen,
        })

        print(f"  Branch {j}: pred={pred}, time={dt:.2f}s")

    t1 = time.time()

    # --- metrics + categorization ---
    metrics = _diversity_metrics(preds)
    correct_frac = _correct_fraction(preds, gold)

    leader = metrics["leader"]
    max_frac = metrics["max_frac"]
    valid_n = metrics["valid_n"]

    # classify into buckets requested
    if valid_n == 0:
        bucket_counts["invalid_all_none"] += 1
        class_label = "invalid_all_none"
        leader_correct = None
    else:
        leader_correct = (leader == gold)

        if metrics["unanimous"]:
            class_label = "unanimous"
            if leader_correct:
                bucket_counts["unanimous_correct"] += 1
            else:
                bucket_counts["unanimous_wrong"] += 1

        elif max_frac >= 0.8:
            class_label = "lead80"
            if leader_correct:
                bucket_counts["lead80_correct"] += 1
            else:
                bucket_counts["lead80_wrong"] += 1

        elif max_frac >= 0.5:
            class_label = "lead50"
            if leader_correct:
                bucket_counts["lead50_correct"] += 1
            else:
                bucket_counts["lead50_wrong"] += 1

        else:
            class_label = "no_leader"
            bucket_counts["no_leader"] += 1

    # --- one-line debug per question (compact) ---
    preds_str = "".join([p if p in ("A","B","C","D") else "_" for p in preds])
    print(
        f" gold={gold} "
        f"preds={preds_str} "
        f"leader={leader} max={max_frac:.2f} "
        f"div={metrics['variation_ratio']:.2f} H={metrics['entropy_bits']:.2f} "
        f"acc={correct_frac:.2f} class={class_label} "
        f"time={t1-t0:.1f}s"
    )

    # --- write FULL record (per example) incrementally ---
    full_record = {
        "index": i,
        "picked_index": picked,
        "id": question_id,
        "question": ex.get("question"),
        "options": {"A": ex.get("opa"), "B": ex.get("opb"), "C": ex.get("opc"), "D": ex.get("opd")},
        "gold": gold,
        "subject_name": subj,
        "model": MODEL_ID,
        "max_new_tokens": MAX_NEW_TOKENS,
        "seed": SEED,
        "timestamp": _now_utc(),
        "branches": branch_records,
        "branch_preds": preds,
        "metrics": {
            **metrics,
            "correct_fraction": correct_frac,
            "leader_correct": leader_correct,
            "class": class_label,
            "wall_time_sec": (t1 - t0),
            "mean_branch_time_sec": sum(branch_times) / max(1, len(branch_times)),
        },
    }
    _append_jsonl(FULL_LOGFILE, full_record)
    logs_full_count += 1

    # --- write SUMMARY record (one line per example) incrementally ---
    summary_record = {
        "index": i,
        "picked_index": picked,
        "id": question_id,
        "gold": gold,
        "branch_preds": preds,
        "leader": leader,
        "max_frac": max_frac,
        "valid_n": valid_n,
        "none_n": metrics["none_n"],
        "variation_ratio": metrics["variation_ratio"],
        "entropy_bits": metrics["entropy_bits"],
        "correct_fraction": correct_frac,
        "leader_correct": leader_correct,
        "class": class_label,
        "subject_name": subj,
        "timestamp": _now_utc(),
    }
    _append_jsonl(BRANCHES_SUMMARY_LOGFILE, summary_record)
    logs_summary_count += 1

    i += 1

t_global1 = time.time()

print("\nInference loop completed.")
print(f"Wrote {logs_full_count} full records to: {FULL_LOGFILE}")
print(f"Wrote {logs_summary_count} summary records to: {BRANCHES_SUMMARY_LOGFILE}")
print(f"Total wall time: {t_global1 - t_global0:.1f}s")

print("\nFinal bucket counts:")
for k in [
    "unanimous_correct", "unanimous_wrong",
    "lead80_correct", "lead80_wrong",
    "lead50_correct", "lead50_wrong",
    "no_leader",
    "invalid_all_none",
]:
    print(f"  {k:18s}: {bucket_counts.get(k, 0)}")

# Optional: also show subject distribution achieved
print("\nSubjects sampled (top 10):")
for s, c in subject_counts.most_common(10):
    print(f"  {s}: {c}")
# Out:
# Starting branching inference loop...
# Processing example index 0 (picked 0/100)...
#  Gold: D, Subject: Pediatrics, Question ID: 4e8f5ba7-452a-464f-a328-d8b96eafade6
#   Branch 0: pred=D, time=24.26s
#   Branch 1: pred=D, time=21.67s
#   Branch 2: pred=D, time=26.43s
#   Branch 3: pred=D, time=25.77s
#   Branch 4: pred=A, time=21.51s
#   Branch 5: pred=D, time=32.27s
#   Branch 6: pred=D, time=19.28s
#   Branch 7: pred=D, time=19.25s
#   Branch 8: pred=D, time=27.76s
#   Branch 9: pred=D, time=24.21s
#  gold=D preds=DDDDADDDDD leader=D max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=242.4s
# Processing example index 1 (picked 1/100)...
#  Gold: A, Subject: Ophthalmology, Question ID: 673a0bbe-b4d8-46bb-83b0-e01658f9f22f
#   Branch 0: pred=A, time=24.63s
#   Branch 1: pred=A, time=27.73s
#   Branch 2: pred=A, time=22.73s
#   Branch 3: pred=A, time=26.11s
#   Branch 4: pred=A, time=25.05s
#   Branch 5: pred=A, time=22.18s
#   Branch 6: pred=A, time=28.86s
#   Branch 7: pred=A, time=21.84s
#   Branch 8: pred=A, time=24.27s
#   Branch 9: pred=A, time=26.38s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=249.8s
# Processing example index 2 (picked 2/100)...
#  Gold: D, Subject: Pharmacology, Question ID: b71747a9-b89b-45b2-a54f-04765341177b
#   Branch 0: pred=A, time=17.41s
#   Branch 1: pred=A, time=20.62s
#   Branch 2: pred=A, time=17.41s
#   Branch 3: pred=A, time=15.46s
#   Branch 4: pred=A, time=19.82s
#   Branch 5: pred=A, time=19.77s
#   Branch 6: pred=A, time=19.55s
#   Branch 7: pred=A, time=20.29s
#   Branch 8: pred=A, time=17.70s
#   Branch 9: pred=A, time=21.78s
#  gold=D preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=0.00 class=unanimous time=189.9s
# Processing example index 3 (picked 3/100)...
#  Gold: B, Subject: Microbiology, Question ID: 7d01f5ce-d737-4838-bf15-68a4dea15b1a
#   Branch 0: pred=B, time=17.09s
#   Branch 1: pred=B, time=16.99s
#   Branch 2: pred=B, time=19.22s
#   Branch 3: pred=B, time=19.83s
#   Branch 4: pred=B, time=18.51s
#   Branch 5: pred=B, time=17.25s
#   Branch 6: pred=B, time=18.91s
#   Branch 7: pred=B, time=17.14s
#   Branch 8: pred=B, time=18.17s
#   Branch 9: pred=B, time=21.89s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=185.0s
# Processing example index 4 (picked 4/100)...
#  Gold: D, Subject: Pharmacology, Question ID: 07c14e46-ad2b-4fde-8652-bd47b36e69ab
#   Branch 0: pred=D, time=21.12s
#   Branch 1: pred=D, time=21.30s
#   Branch 2: pred=D, time=20.40s
#   Branch 3: pred=D, time=24.25s
#   Branch 4: pred=D, time=24.59s
#   Branch 5: pred=D, time=24.30s
#   Branch 6: pred=D, time=26.99s
#   Branch 7: pred=D, time=19.80s
#   Branch 8: pred=D, time=20.21s
#   Branch 9: pred=D, time=20.32s
#  gold=D preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=223.3s
# Processing example index 5 (picked 5/100)...
#  Gold: D, Subject: Pathology, Question ID: 22f37095-b0aa-4603-a72d-8594c37b6f7e
#   Branch 0: pred=B, time=21.87s
#   Branch 1: pred=B, time=20.85s
#   Branch 2: pred=B, time=20.83s
#   Branch 3: pred=B, time=28.04s
#   Branch 4: pred=B, time=18.46s
#   Branch 5: pred=B, time=21.11s
#   Branch 6: pred=B, time=26.27s
#   Branch 7: pred=B, time=19.12s
#   Branch 8: pred=B, time=22.16s
#   Branch 9: pred=B, time=30.73s
#  gold=D preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=0.00 class=unanimous time=229.5s
# Processing example index 6 (picked 6/100)...
#  Gold: A, Subject: Anatomy, Question ID: 883563e3-4fe8-4b33-926b-5237f09d9c60
#   Branch 0: pred=A, time=18.34s
#   Branch 1: pred=A, time=21.09s
#   Branch 2: pred=A, time=22.16s
#   Branch 3: pred=A, time=19.75s
#   Branch 4: pred=A, time=16.63s
#   Branch 5: pred=A, time=17.93s
#   Branch 6: pred=A, time=16.70s
#   Branch 7: pred=A, time=18.68s
#   Branch 8: pred=A, time=17.00s
#   Branch 9: pred=A, time=20.05s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=188.4s
# Processing example index 7 (picked 7/100)...
#  Gold: B, Subject: Surgery, Question ID: a9eacca0-36c6-4171-996c-d7c4d75f42df
#   Branch 0: pred=B, time=28.55s
#   Branch 1: pred=B, time=18.94s
#   Branch 2: pred=A, time=19.45s
#   Branch 3: pred=None, time=17.69s
#   Branch 4: pred=A, time=23.34s
#   Branch 5: pred=A, time=23.24s
#   Branch 6: pred=C, time=18.79s
#   Branch 7: pred=A, time=18.67s
#   Branch 8: pred=B, time=37.74s
#   Branch 9: pred=A, time=18.42s
#  gold=B preds=BBA_AACABA leader=A max=0.56 div=0.44 H=1.35 acc=0.33 class=lead50 time=224.9s
# Processing example index 8 (picked 8/100)...
#  Gold: C, Subject: Social & Preventive Medicine, Question ID: 579951c3-517c-41e4-ac39-0a48f474c01b
#   Branch 0: pred=A, time=24.36s
#   Branch 1: pred=D, time=49.28s
#   Branch 2: pred=B, time=21.05s
#   Branch 3: pred=B, time=24.46s
#   Branch 4: pred=A, time=12.88s
#   Branch 5: pred=C, time=16.87s
#   Branch 6: pred=C, time=13.88s
#   Branch 7: pred=A, time=49.76s
#   Branch 8: pred=A, time=49.53s
#   Branch 9: pred=C, time=16.39s
#  gold=C preds=ADBBACCAAC leader=A max=0.40 div=0.60 H=1.85 acc=0.30 class=no_leader time=278.5s
# Processing example index 9 (picked 9/100)...
#  Gold: B, Subject: Dental, Question ID: 17cb7e3f-0ca7-4937-a407-76bf9f401143
#   Branch 0: pred=A, time=29.44s
#   Branch 1: pred=B, time=25.95s
#   Branch 2: pred=C, time=37.46s
#   Branch 3: pred=A, time=31.96s
#   Branch 4: pred=D, time=28.12s
#   Branch 5: pred=B, time=48.72s
#   Branch 6: pred=A, time=27.53s
#   Branch 7: pred=A, time=29.29s
#   Branch 8: pred=B, time=43.56s
#   Branch 9: pred=D, time=30.46s
#  gold=B preds=ABCADBAABD leader=A max=0.40 div=0.60 H=1.85 acc=0.30 class=no_leader time=332.5s
# Processing example index 10 (picked 10/100)...
#  Gold: B, Subject: Dental, Question ID: efa0e92a-b11b-4c1c-a97d-8b4409430caa
#   Branch 0: pred=B, time=21.60s
#   Branch 1: pred=D, time=20.93s
#   Branch 2: pred=B, time=24.89s
#   Branch 3: pred=D, time=20.79s
#   Branch 4: pred=D, time=19.46s
#   Branch 5: pred=D, time=27.91s
#   Branch 6: pred=C, time=18.30s
#   Branch 7: pred=D, time=15.99s
#   Branch 8: pred=C, time=28.51s
#   Branch 9: pred=D, time=20.61s
#  gold=B preds=BDBDDDCDCD leader=D max=0.60 div=0.40 H=1.37 acc=0.20 class=lead50 time=219.0s
# Processing example index 11 (picked 11/100)...
#  Gold: A, Subject: Anatomy, Question ID: 8adc8a84-b0a1-4b6c-b076-91ba05e9a37e
#   Branch 0: pred=B, time=20.46s
#   Branch 1: pred=B, time=23.26s
#   Branch 2: pred=B, time=18.77s
#   Branch 3: pred=B, time=18.44s
#   Branch 4: pred=B, time=18.39s
#   Branch 5: pred=A, time=22.04s
#   Branch 6: pred=B, time=25.44s
#   Branch 7: pred=B, time=20.54s
#   Branch 8: pred=B, time=20.18s
#   Branch 9: pred=B, time=18.27s
#  gold=A preds=BBBBBABBBB leader=B max=0.90 div=0.10 H=0.47 acc=0.10 class=lead80 time=205.8s
# Processing example index 12 (picked 12/100)...
#  Gold: B, Subject: Biochemistry, Question ID: 0cd0e1c4-aabe-4ac3-ae2b-83b0633cb376
#   Branch 0: pred=B, time=27.47s
#   Branch 1: pred=B, time=21.85s
#   Branch 2: pred=B, time=28.98s
#   Branch 3: pred=B, time=24.04s
#   Branch 4: pred=B, time=24.12s
#   Branch 5: pred=B, time=28.50s
#   Branch 6: pred=B, time=23.57s
#   Branch 7: pred=B, time=26.22s
#   Branch 8: pred=B, time=22.63s
#   Branch 9: pred=B, time=28.80s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=256.2s
# Processing example index 13 (picked 13/100)...
#  Gold: D, Subject: Gynaecology & Obstetrics, Question ID: 8ec544be-913f-4b14-9858-8026a462af96
#   Branch 0: pred=D, time=28.84s
#   Branch 1: pred=D, time=26.16s
#   Branch 2: pred=D, time=26.02s
#   Branch 3: pred=D, time=26.39s
#   Branch 4: pred=D, time=28.75s
#   Branch 5: pred=D, time=27.80s
#   Branch 6: pred=D, time=26.75s
#   Branch 7: pred=D, time=24.59s
#   Branch 8: pred=D, time=30.08s
#   Branch 9: pred=D, time=23.26s
#  gold=D preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=268.7s
# Processing example index 14 (picked 14/100)...
#  Gold: A, Subject: Radiology, Question ID: 427b1e29-9386-4ca4-af88-7c3fe4b37e15
#   Branch 0: pred=A, time=17.67s
#   Branch 1: pred=B, time=20.31s
#   Branch 2: pred=A, time=22.55s
#   Branch 3: pred=A, time=18.48s
#   Branch 4: pred=A, time=24.75s
#   Branch 5: pred=A, time=17.26s
#   Branch 6: pred=A, time=23.37s
#   Branch 7: pred=A, time=18.16s
#   Branch 8: pred=A, time=19.11s
#   Branch 9: pred=A, time=20.75s
#  gold=A preds=ABAAAAAAAA leader=A max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=202.4s
# Processing example index 15 (picked 15/100)...
#  Gold: B, Subject: Pediatrics, Question ID: 893ad532-01e8-421e-ac71-d5e8dfb882e5
#   Branch 0: pred=A, time=20.16s
#   Branch 1: pred=C, time=21.01s
#   Branch 2: pred=A, time=18.75s
#   Branch 3: pred=A, time=19.85s
#   Branch 4: pred=B, time=23.13s
#   Branch 5: pred=A, time=17.61s
#   Branch 6: pred=B, time=17.40s
#   Branch 7: pred=B, time=15.31s
#   Branch 8: pred=A, time=18.85s
#   Branch 9: pred=A, time=19.10s
#  gold=B preds=ACAABABBAA leader=A max=0.60 div=0.40 H=1.30 acc=0.30 class=lead50 time=191.2s
# Processing example index 16 (picked 16/100)...
#  Gold: C, Subject: Physiology, Question ID: ca435de5-729e-4d62-8d92-116f5afb5a48
#   Branch 0: pred=C, time=22.48s
#   Branch 1: pred=C, time=24.52s
#   Branch 2: pred=C, time=24.80s
#   Branch 3: pred=C, time=22.46s
#   Branch 4: pred=C, time=29.01s
#   Branch 5: pred=C, time=25.87s
#   Branch 6: pred=D, time=20.79s
#   Branch 7: pred=A, time=49.81s
#   Branch 8: pred=C, time=25.14s
#   Branch 9: pred=B, time=28.11s
#  gold=C preds=CCCCCCDACB leader=C max=0.70 div=0.30 H=1.36 acc=0.70 class=lead50 time=273.0s
# Processing example index 17 (picked 17/100)...
#  Gold: B, Subject: Dental, Question ID: abd507d7-232c-46cb-8605-cb573b86ee2b
#   Branch 0: pred=A, time=13.60s
#   Branch 1: pred=B, time=20.22s
#   Branch 2: pred=B, time=16.24s
#   Branch 3: pred=B, time=17.90s
#   Branch 4: pred=A, time=15.20s
#   Branch 5: pred=A, time=12.71s
#   Branch 6: pred=A, time=12.99s
#   Branch 7: pred=B, time=14.59s
#   Branch 8: pred=C, time=14.17s
#   Branch 9: pred=B, time=16.03s
#  gold=B preds=ABBBAAABCB leader=B max=0.50 div=0.50 H=1.36 acc=0.50 class=lead50 time=153.7s
# Processing example index 18 (picked 18/100)...
#  Gold: A, Subject: Medicine, Question ID: b1cc4ab0-a82c-437a-88c2-00953f3618ff
#   Branch 0: pred=A, time=24.92s
#   Branch 1: pred=A, time=22.27s
#   Branch 2: pred=A, time=23.14s
#   Branch 3: pred=A, time=19.66s
#   Branch 4: pred=A, time=21.84s
#   Branch 5: pred=B, time=23.40s
#   Branch 6: pred=B, time=24.37s
#   Branch 7: pred=A, time=22.37s
#   Branch 8: pred=A, time=24.40s
#   Branch 9: pred=A, time=24.33s
#  gold=A preds=AAAAABBAAA leader=A max=0.80 div=0.20 H=0.72 acc=0.80 class=lead80 time=230.8s
# Processing example index 19 (picked 19/100)...
#  Gold: C, Subject: Gynaecology & Obstetrics, Question ID: 621316dd-5ef8-4ba1-953c-6f214b414b56
#   Branch 0: pred=C, time=21.85s
#   Branch 1: pred=C, time=19.95s
#   Branch 2: pred=C, time=23.19s
#   Branch 3: pred=C, time=20.33s
#   Branch 4: pred=C, time=23.47s
#   Branch 5: pred=C, time=23.18s
#   Branch 6: pred=A, time=21.11s
#   Branch 7: pred=C, time=24.08s
#   Branch 8: pred=C, time=21.38s
#   Branch 9: pred=C, time=16.73s
#  gold=C preds=CCCCCCACCC leader=C max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=215.3s
# Processing example index 20 (picked 20/100)...
#  Gold: A, Subject: Pharmacology, Question ID: c4169d37-8378-47f0-a9e6-6ae62b6046fd
#   Branch 0: pred=A, time=21.88s
#   Branch 1: pred=A, time=19.28s
#   Branch 2: pred=A, time=21.59s
#   Branch 3: pred=A, time=22.41s
#   Branch 4: pred=A, time=18.66s
#   Branch 5: pred=A, time=17.96s
#   Branch 6: pred=A, time=19.64s
#   Branch 7: pred=A, time=19.68s
#   Branch 8: pred=A, time=19.98s
#   Branch 9: pred=C, time=19.36s
#  gold=A preds=AAAAAAAAAC leader=A max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=200.5s
# Processing example index 21 (picked 21/100)...
#  Gold: C, Subject: ENT, Question ID: 9bad2095-2dd9-4485-946a-4ef51d16e8a4
#   Branch 0: pred=B, time=20.60s
#   Branch 1: pred=B, time=22.58s
#   Branch 2: pred=C, time=23.76s
#   Branch 3: pred=B, time=20.85s
#   Branch 4: pred=B, time=18.58s
#   Branch 5: pred=C, time=20.28s
#   Branch 6: pred=B, time=20.33s
#   Branch 7: pred=B, time=23.05s
#   Branch 8: pred=B, time=21.42s
#   Branch 9: pred=B, time=20.23s
#  gold=C preds=BBCBBCBBBB leader=B max=0.80 div=0.20 H=0.72 acc=0.20 class=lead80 time=211.7s
# Processing example index 22 (picked 22/100)...
#  Gold: D, Subject: Pathology, Question ID: f3f3ad74-951f-4907-913d-f5c6c6c2dd2a
#   Branch 0: pred=D, time=13.91s
#   Branch 1: pred=D, time=28.74s
#   Branch 2: pred=B, time=15.32s
#   Branch 3: pred=D, time=15.52s
#   Branch 4: pred=B, time=14.95s
#   Branch 5: pred=D, time=14.30s
#   Branch 6: pred=D, time=24.37s
#   Branch 7: pred=D, time=32.07s
#   Branch 8: pred=D, time=15.77s
#   Branch 9: pred=D, time=22.22s
#  gold=D preds=DDBDBDDDDD leader=D max=0.80 div=0.20 H=0.72 acc=0.80 class=lead80 time=197.2s
# Processing example index 23 (picked 23/100)...
#  Gold: B, Subject: Pathology, Question ID: 4e6da460-99e2-4192-b3b6-b10f8827dce2
#   Branch 0: pred=B, time=15.08s
#   Branch 1: pred=C, time=19.41s
#   Branch 2: pred=C, time=20.35s
#   Branch 3: pred=B, time=13.33s
#   Branch 4: pred=A, time=19.18s
#   Branch 5: pred=A, time=18.83s
#   Branch 6: pred=A, time=18.25s
#   Branch 7: pred=C, time=15.72s
#   Branch 8: pred=A, time=19.99s
#   Branch 9: pred=A, time=17.14s
#  gold=B preds=BCCBAAACAA leader=A max=0.50 div=0.50 H=1.49 acc=0.20 class=lead50 time=177.3s
# Processing example index 24 (picked 24/100)...
#  Gold: D, Subject: Pathology, Question ID: 592c91f5-5a59-44d3-b19b-08d036762a1b
#   Branch 0: pred=A, time=29.20s
#   Branch 1: pred=A, time=26.66s
#   Branch 2: pred=A, time=28.82s
#   Branch 3: pred=B, time=28.26s
#   Branch 4: pred=A, time=29.02s
#   Branch 5: pred=A, time=24.49s
#   Branch 6: pred=A, time=29.89s
#   Branch 7: pred=C, time=43.07s
#   Branch 8: pred=A, time=25.85s
#   Branch 9: pred=B, time=27.04s
#  gold=D preds=AAABAAACAB leader=A max=0.70 div=0.30 H=1.16 acc=0.00 class=lead50 time=292.3s
# Processing example index 25 (picked 25/100)...
#  Gold: A, Subject: Orthopaedics, Question ID: b6b91d49-7a30-4a9a-91e6-b2f20341470c
#   Branch 0: pred=A, time=14.19s
#   Branch 1: pred=A, time=12.68s
#   Branch 2: pred=A, time=14.80s
#   Branch 3: pred=A, time=13.16s
#   Branch 4: pred=A, time=15.64s
#   Branch 5: pred=A, time=14.87s
#   Branch 6: pred=A, time=16.09s
#   Branch 7: pred=A, time=14.47s
#   Branch 8: pred=A, time=13.01s
#   Branch 9: pred=A, time=12.93s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=141.9s
# Processing example index 26 (picked 26/100)...
#  Gold: A, Subject: Radiology, Question ID: 41de4a10-ea29-4f5d-817c-570c5e537bc9
#   Branch 0: pred=A, time=26.73s
#   Branch 1: pred=D, time=21.58s
#   Branch 2: pred=C, time=19.87s
#   Branch 3: pred=C, time=22.76s
#   Branch 4: pred=D, time=20.33s
#   Branch 5: pred=D, time=22.06s
#   Branch 6: pred=D, time=19.80s
#   Branch 7: pred=C, time=21.10s
#   Branch 8: pred=D, time=19.04s
#   Branch 9: pred=D, time=18.45s
#  gold=A preds=ADCCDDDCDD leader=D max=0.60 div=0.40 H=1.30 acc=0.10 class=lead50 time=211.8s
# Processing example index 27 (picked 27/100)...
#  Gold: B, Subject: Surgery, Question ID: 1f253e11-f50e-40f8-a36a-16101d47d319
#   Branch 0: pred=B, time=14.94s
#   Branch 1: pred=B, time=17.28s
#   Branch 2: pred=B, time=14.16s
#   Branch 3: pred=B, time=13.27s
#   Branch 4: pred=B, time=13.69s
#   Branch 5: pred=B, time=15.84s
#   Branch 6: pred=A, time=18.46s
#   Branch 7: pred=B, time=15.39s
#   Branch 8: pred=B, time=13.58s
#   Branch 9: pred=B, time=11.33s
#  gold=B preds=BBBBBBABBB leader=B max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=148.0s
# Processing example index 28 (picked 28/100)...
#  Gold: D, Subject: Dental, Question ID: 478d3388-e6a4-49a7-8c07-7b9f6f6c19b8
#   Branch 0: pred=B, time=25.95s
#   Branch 1: pred=A, time=25.56s
#   Branch 2: pred=A, time=21.72s
#   Branch 3: pred=A, time=38.00s
#   Branch 4: pred=A, time=24.14s
#   Branch 5: pred=A, time=23.85s
#   Branch 6: pred=A, time=27.96s
#   Branch 7: pred=A, time=29.49s
#   Branch 8: pred=D, time=22.42s
#   Branch 9: pred=A, time=24.71s
#  gold=D preds=BAAAAAAADA leader=A max=0.80 div=0.20 H=0.92 acc=0.10 class=lead80 time=263.8s
# Processing example index 29 (picked 29/100)...
#  Gold: B, Subject: Social & Preventive Medicine, Question ID: b0d25fa2-56a0-4b68-aaaf-0bc455e055be
#   Branch 0: pred=B, time=8.96s
#   Branch 1: pred=B, time=5.95s
#   Branch 2: pred=B, time=7.52s
#   Branch 3: pred=B, time=8.69s
#   Branch 4: pred=B, time=7.94s
#   Branch 5: pred=B, time=9.45s
#   Branch 6: pred=B, time=6.99s
#   Branch 7: pred=B, time=6.79s
#   Branch 8: pred=B, time=7.48s
#   Branch 9: pred=B, time=7.47s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=77.3s
# Processing example index 30 (picked 30/100)...
#  Gold: B, Subject: Surgery, Question ID: 23022df5-e07c-40f9-9f79-b3adff072f5e
#   Branch 0: pred=B, time=26.39s
#   Branch 1: pred=B, time=25.97s
#   Branch 2: pred=B, time=26.64s
#   Branch 3: pred=B, time=29.42s
#   Branch 4: pred=B, time=23.05s
#   Branch 5: pred=B, time=26.80s
#   Branch 6: pred=B, time=25.97s
#   Branch 7: pred=B, time=25.43s
#   Branch 8: pred=B, time=25.18s
#   Branch 9: pred=B, time=25.96s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=260.9s
# Processing example index 31 (picked 31/100)...
#  Gold: C, Subject: Dental, Question ID: d321d320-c06f-4d18-9aa2-dae718851dfd
#   Branch 0: pred=A, time=18.18s
#   Branch 1: pred=A, time=21.91s
#   Branch 2: pred=A, time=22.86s
#   Branch 3: pred=A, time=27.35s
#   Branch 4: pred=A, time=21.36s
#   Branch 5: pred=A, time=14.74s
#   Branch 6: pred=A, time=19.26s
#   Branch 7: pred=A, time=15.99s
#   Branch 8: pred=A, time=17.97s
#   Branch 9: pred=A, time=16.30s
#  gold=C preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=0.00 class=unanimous time=195.9s
# Processing example index 32 (picked 32/100)...
#  Gold: B, Subject: Medicine, Question ID: e7173db8-8f12-46b3-a2e8-86eaa2574855
#   Branch 0: pred=D, time=23.24s
#   Branch 1: pred=B, time=23.58s
#   Branch 2: pred=D, time=23.99s
#   Branch 3: pred=D, time=20.02s
#   Branch 4: pred=D, time=25.66s
#   Branch 5: pred=D, time=22.68s
#   Branch 6: pred=D, time=34.73s
#   Branch 7: pred=B, time=32.95s
#   Branch 8: pred=D, time=21.90s
#   Branch 9: pred=D, time=22.09s
#  gold=B preds=DBDDDDDBDD leader=D max=0.80 div=0.20 H=0.72 acc=0.20 class=lead80 time=250.9s
# Processing example index 33 (picked 33/100)...
#  Gold: B, Subject: Pediatrics, Question ID: bf8d5b76-bda5-4221-95ef-d536c00c24ee
#   Branch 0: pred=B, time=20.05s
#   Branch 1: pred=B, time=16.05s
#   Branch 2: pred=B, time=18.44s
#   Branch 3: pred=B, time=18.40s
#   Branch 4: pred=B, time=17.40s
#   Branch 5: pred=B, time=16.53s
#   Branch 6: pred=B, time=18.83s
#   Branch 7: pred=B, time=20.29s
#   Branch 8: pred=B, time=17.70s
#   Branch 9: pred=B, time=21.57s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=185.3s
# Processing example index 34 (picked 34/100)...
#  Gold: C, Subject: Social & Preventive Medicine, Question ID: 8be0f11a-fb38-4996-95b7-b3fcf36de7c4
#   Branch 0: pred=C, time=18.72s
#   Branch 1: pred=C, time=17.38s
#   Branch 2: pred=C, time=13.43s
#   Branch 3: pred=C, time=16.92s
#   Branch 4: pred=C, time=19.28s
#   Branch 5: pred=C, time=27.16s
#   Branch 6: pred=A, time=49.63s
#   Branch 7: pred=C, time=12.72s
#   Branch 8: pred=C, time=21.31s
#   Branch 9: pred=C, time=15.10s
#  gold=C preds=CCCCCCACCC leader=C max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=211.7s
# Processing example index 35 (picked 35/100)...
#  Gold: B, Subject: Ophthalmology, Question ID: 8cce7868-0429-4f98-9e6a-4baa045dffcc
#   Branch 0: pred=B, time=30.35s
#   Branch 1: pred=B, time=28.97s
#   Branch 2: pred=B, time=26.75s
#   Branch 3: pred=D, time=30.55s
#   Branch 4: pred=B, time=26.96s
#   Branch 5: pred=B, time=28.39s
#   Branch 6: pred=B, time=27.88s
#   Branch 7: pred=B, time=31.75s
#   Branch 8: pred=B, time=31.26s
#   Branch 9: pred=B, time=29.21s
#  gold=B preds=BBBDBBBBBB leader=B max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=292.1s
# Processing example index 36 (picked 36/100)...
#  Gold: B, Subject: Gynaecology & Obstetrics, Question ID: ab34e961-f641-4c92-9324-06da16cc52ef
#   Branch 0: pred=B, time=18.34s
#   Branch 1: pred=A, time=49.90s
#   Branch 2: pred=B, time=25.57s
#   Branch 3: pred=B, time=22.52s
#   Branch 4: pred=B, time=14.01s
#   Branch 5: pred=A, time=49.71s
#   Branch 6: pred=B, time=27.51s
#   Branch 7: pred=B, time=23.48s
#   Branch 8: pred=B, time=15.84s
#   Branch 9: pred=A, time=49.86s
#  gold=B preds=BABBBABBBA leader=B max=0.70 div=0.30 H=0.88 acc=0.70 class=lead50 time=296.8s
# Processing example index 37 (picked 37/100)...
#  Gold: C, Subject: Gynaecology & Obstetrics, Question ID: e5e1f694-5bce-4ea7-8d47-b629076533e1
#   Branch 0: pred=C, time=18.84s
#   Branch 1: pred=C, time=20.07s
#   Branch 2: pred=C, time=17.57s
#   Branch 3: pred=C, time=19.47s
#   Branch 4: pred=C, time=17.75s
#   Branch 5: pred=B, time=21.56s
#   Branch 6: pred=C, time=19.49s
#   Branch 7: pred=C, time=21.17s
#   Branch 8: pred=C, time=18.10s
#   Branch 9: pred=C, time=18.92s
#  gold=C preds=CCCCCBCCCC leader=C max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=193.0s
# Processing example index 38 (picked 38/100)...
#  Gold: A, Subject: Anatomy, Question ID: 3844fc33-c5f5-48b4-ad6b-45dc4a3ec3c4
#   Branch 0: pred=D, time=19.35s
#   Branch 1: pred=A, time=14.32s
#   Branch 2: pred=A, time=49.90s
#   Branch 3: pred=A, time=21.85s
#   Branch 4: pred=A, time=12.87s
#   Branch 5: pred=A, time=15.95s
#   Branch 6: pred=A, time=17.02s
#   Branch 7: pred=A, time=17.99s
#   Branch 8: pred=A, time=15.23s
#   Branch 9: pred=C, time=29.09s
#  gold=A preds=DAAAAAAAAC leader=A max=0.80 div=0.20 H=0.92 acc=0.80 class=lead80 time=213.6s
# Processing example index 39 (picked 39/100)...
#  Gold: B, Subject: Anatomy, Question ID: d3a7afa0-b887-4c0b-a244-6c41e2f62ee4
#   Branch 0: pred=B, time=15.94s
#   Branch 1: pred=B, time=16.73s
#   Branch 2: pred=B, time=16.86s
#   Branch 3: pred=B, time=16.75s
#   Branch 4: pred=B, time=17.84s
#   Branch 5: pred=B, time=17.13s
#   Branch 6: pred=B, time=17.64s
#   Branch 7: pred=B, time=17.81s
#   Branch 8: pred=B, time=17.11s
#   Branch 9: pred=B, time=17.39s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=171.2s
# Processing example index 40 (picked 40/100)...
#  Gold: B, Subject: Gynaecology & Obstetrics, Question ID: 80373cf9-5322-408c-ae6b-bff7f9fb2d88
#   Branch 0: pred=D, time=21.04s
#   Branch 1: pred=A, time=20.49s
#   Branch 2: pred=B, time=19.29s
#   Branch 3: pred=B, time=19.74s
#   Branch 4: pred=D, time=26.34s
#   Branch 5: pred=B, time=17.16s
#   Branch 6: pred=D, time=23.60s
#   Branch 7: pred=D, time=20.46s
#   Branch 8: pred=C, time=22.51s
#   Branch 9: pred=A, time=28.71s
#  gold=B preds=DABBDBDDCA leader=D max=0.40 div=0.60 H=1.85 acc=0.30 class=no_leader time=219.4s
# Processing example index 41 (picked 41/100)...
#  Gold: D, Subject: Anatomy, Question ID: d810c51c-b15e-40e7-9d7c-2eff29038877
#   Branch 0: pred=B, time=19.80s
#   Branch 1: pred=B, time=21.55s
#   Branch 2: pred=D, time=19.18s
#   Branch 3: pred=B, time=28.71s
#   Branch 4: pred=B, time=19.94s
#   Branch 5: pred=B, time=21.06s
#   Branch 6: pred=B, time=20.66s
#   Branch 7: pred=B, time=21.02s
#   Branch 8: pred=B, time=26.07s
#   Branch 9: pred=D, time=16.14s
#  gold=D preds=BBDBBBBBBD leader=B max=0.80 div=0.20 H=0.72 acc=0.20 class=lead80 time=214.2s
# Processing example index 42 (picked 42/100)...
#  Gold: B, Subject: Surgery, Question ID: ccec60b1-80b6-4130-b1ab-8631cac2fa14
#   Branch 0: pred=B, time=17.34s
#   Branch 1: pred=B, time=15.81s
#   Branch 2: pred=B, time=16.54s
#   Branch 3: pred=B, time=17.12s
#   Branch 4: pred=B, time=22.30s
#   Branch 5: pred=B, time=16.59s
#   Branch 6: pred=B, time=17.71s
#   Branch 7: pred=B, time=20.27s
#   Branch 8: pred=B, time=17.64s
#   Branch 9: pred=B, time=19.98s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=181.3s
# Processing example index 43 (picked 43/100)...
#  Gold: D, Subject: Medicine, Question ID: 789aa0f7-2666-4950-be7e-42b03b1b1a44
#   Branch 0: pred=D, time=16.42s
#   Branch 1: pred=D, time=17.06s
#   Branch 2: pred=D, time=16.63s
#   Branch 3: pred=D, time=19.54s
#   Branch 4: pred=D, time=17.79s
#   Branch 5: pred=D, time=17.64s
#   Branch 6: pred=D, time=18.96s
#   Branch 7: pred=D, time=16.94s
#   Branch 8: pred=D, time=15.47s
#   Branch 9: pred=D, time=15.95s
#  gold=D preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=172.4s
# Processing example index 44 (picked 44/100)...
#  Gold: C, Subject: Pharmacology, Question ID: c3b4d610-571b-4e86-be27-d41b8b2efc65
#   Branch 0: pred=C, time=17.05s
#   Branch 1: pred=C, time=21.02s
#   Branch 2: pred=C, time=20.18s
#   Branch 3: pred=C, time=17.87s
#   Branch 4: pred=C, time=18.37s
#   Branch 5: pred=C, time=20.65s
#   Branch 6: pred=C, time=22.86s
#   Branch 7: pred=C, time=18.84s
#   Branch 8: pred=C, time=18.66s
#   Branch 9: pred=C, time=19.72s
#  gold=C preds=CCCCCCCCCC leader=C max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=195.3s
# Processing example index 45 (picked 45/100)...
#  Gold: A, Subject: Physiology, Question ID: 98893c1c-a979-476e-8b82-ef3bd2a02da7
#   Branch 0: pred=A, time=21.03s
#   Branch 1: pred=A, time=22.81s
#   Branch 2: pred=A, time=20.45s
#   Branch 3: pred=A, time=19.84s
#   Branch 4: pred=A, time=17.41s
#   Branch 5: pred=A, time=19.85s
#   Branch 6: pred=A, time=18.64s
#   Branch 7: pred=A, time=19.88s
#   Branch 8: pred=A, time=18.11s
#   Branch 9: pred=A, time=21.72s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=199.8s
# Processing example index 46 (picked 46/100)...
#  Gold: A, Subject: Surgery, Question ID: 62081a5c-5ffc-4a88-9aca-c9e430490e73
#   Branch 0: pred=A, time=20.52s
#   Branch 1: pred=A, time=20.58s
#   Branch 2: pred=A, time=18.83s
#   Branch 3: pred=A, time=18.26s
#   Branch 4: pred=A, time=21.13s
#   Branch 5: pred=A, time=20.70s
#   Branch 6: pred=A, time=19.36s
#   Branch 7: pred=A, time=17.68s
#   Branch 8: pred=A, time=19.02s
#   Branch 9: pred=A, time=18.23s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=194.3s
# Processing example index 47 (picked 47/100)...
#  Gold: D, Subject: Medicine, Question ID: 37439d71-3558-4ceb-85af-8332c259afe1
#   Branch 0: pred=A, time=26.19s
#   Branch 1: pred=C, time=34.57s
#   Branch 2: pred=A, time=50.05s
#   Branch 3: pred=D, time=30.08s
#   Branch 4: pred=A, time=49.81s
#   Branch 5: pred=A, time=49.53s
#   Branch 6: pred=A, time=31.93s
#   Branch 7: pred=D, time=33.84s
#   Branch 8: pred=A, time=41.75s
#   Branch 9: pred=A, time=49.49s
#  gold=D preds=ACADAAADAA leader=A max=0.70 div=0.30 H=1.16 acc=0.20 class=lead50 time=397.3s
# Processing example index 48 (picked 48/100)...
#  Gold: A, Subject: Surgery, Question ID: 90d38496-3baf-4df8-a4ce-5210d0dbfa0f
#   Branch 0: pred=A, time=15.81s
#   Branch 1: pred=C, time=14.08s
#   Branch 2: pred=D, time=14.28s
#   Branch 3: pred=A, time=15.82s
#   Branch 4: pred=B, time=17.87s
#   Branch 5: pred=D, time=13.76s
#   Branch 6: pred=D, time=15.46s
#   Branch 7: pred=D, time=14.66s
#   Branch 8: pred=A, time=14.18s
#   Branch 9: pred=D, time=14.65s
#  gold=A preds=ACDABDDDAD leader=D max=0.50 div=0.50 H=1.69 acc=0.30 class=lead50 time=150.6s
# Processing example index 49 (picked 49/100)...
#  Gold: B, Subject: Gynaecology & Obstetrics, Question ID: 93d8bac0-76ae-4440-91c0-fa3b724bbc65
#   Branch 0: pred=D, time=21.20s
#   Branch 1: pred=B, time=16.02s
#   Branch 2: pred=D, time=18.35s
#   Branch 3: pred=B, time=18.87s
#   Branch 4: pred=B, time=18.96s
#   Branch 5: pred=D, time=18.98s
#   Branch 6: pred=D, time=20.81s
#   Branch 7: pred=D, time=20.71s
#   Branch 8: pred=D, time=18.83s
#   Branch 9: pred=D, time=16.38s
#  gold=B preds=DBDBBDDDDD leader=D max=0.70 div=0.30 H=0.88 acc=0.30 class=lead50 time=189.1s
# Processing example index 50 (picked 50/100)...
#  Gold: C, Subject: Anatomy, Question ID: 95567c10-0007-466a-8b8e-8f8891806716
#   Branch 0: pred=C, time=18.70s
#   Branch 1: pred=C, time=23.29s
#   Branch 2: pred=C, time=22.64s
#   Branch 3: pred=D, time=25.25s
#   Branch 4: pred=D, time=22.49s
#   Branch 5: pred=C, time=21.81s
#   Branch 6: pred=D, time=44.14s
#   Branch 7: pred=C, time=18.74s
#   Branch 8: pred=C, time=21.45s
#   Branch 9: pred=C, time=19.50s
#  gold=C preds=CCCDDCDCCC leader=C max=0.70 div=0.30 H=0.88 acc=0.70 class=lead50 time=238.0s
# Processing example index 51 (picked 51/100)...
#  Gold: B, Subject: Pharmacology, Question ID: a30f9a2b-52f0-4880-980d-d56de2a88910
#   Branch 0: pred=D, time=26.11s
#   Branch 1: pred=A, time=30.11s
#   Branch 2: pred=A, time=21.95s
#   Branch 3: pred=D, time=25.14s
#   Branch 4: pred=D, time=29.23s
#   Branch 5: pred=D, time=26.41s
#   Branch 6: pred=D, time=27.34s
#   Branch 7: pred=D, time=23.66s
#   Branch 8: pred=D, time=25.47s
#   Branch 9: pred=D, time=43.90s
#  gold=B preds=DAADDDDDDD leader=D max=0.80 div=0.20 H=0.72 acc=0.00 class=lead80 time=279.4s
# Processing example index 52 (picked 52/100)...
#  Gold: D, Subject: Anatomy, Question ID: 93c4a1a4-7b8b-4d71-b246-3125604bc899
#   Branch 0: pred=D, time=19.32s
#   Branch 1: pred=D, time=14.15s
#   Branch 2: pred=D, time=14.10s
#   Branch 3: pred=D, time=16.39s
#   Branch 4: pred=D, time=15.66s
#   Branch 5: pred=D, time=14.22s
#   Branch 6: pred=D, time=15.91s
#   Branch 7: pred=D, time=16.03s
#   Branch 8: pred=D, time=17.23s
#   Branch 9: pred=D, time=14.44s
#  gold=D preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=157.5s
# Processing example index 53 (picked 53/100)...
#  Gold: A, Subject: Pathology, Question ID: b18e044b-bb0e-4046-ad9e-3b0d3a5beaa5
#   Branch 0: pred=B, time=25.61s
#   Branch 1: pred=A, time=20.78s
#   Branch 2: pred=A, time=24.18s
#   Branch 3: pred=A, time=23.09s
#   Branch 4: pred=A, time=19.03s
#   Branch 5: pred=A, time=22.15s
#   Branch 6: pred=A, time=20.34s
#   Branch 7: pred=A, time=19.75s
#   Branch 8: pred=C, time=21.83s
#   Branch 9: pred=A, time=19.66s
#  gold=A preds=BAAAAAAACA leader=A max=0.80 div=0.20 H=0.92 acc=0.80 class=lead80 time=216.5s
# Processing example index 54 (picked 54/100)...
#  Gold: C, Subject: Gynaecology & Obstetrics, Question ID: 762b1d6e-6206-45cf-baa7-55b1c14d5fb1
#   Branch 0: pred=A, time=15.82s
#   Branch 1: pred=C, time=14.73s
#   Branch 2: pred=C, time=16.65s
#   Branch 3: pred=C, time=12.79s
#   Branch 4: pred=C, time=31.27s
#   Branch 5: pred=C, time=15.64s
#   Branch 6: pred=C, time=16.20s
#   Branch 7: pred=C, time=16.90s
#   Branch 8: pred=C, time=13.77s
#   Branch 9: pred=C, time=13.77s
#  gold=C preds=ACCCCCCCCC leader=C max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=167.6s
# Processing example index 55 (picked 55/100)...
#  Gold: A, Subject: Forensic Medicine, Question ID: 5c578aa4-a6fd-4de5-b0f6-adb926564122
#   Branch 0: pred=B, time=19.37s
#   Branch 1: pred=B, time=46.29s
#   Branch 2: pred=A, time=26.87s
#   Branch 3: pred=B, time=32.18s
#   Branch 4: pred=B, time=46.99s
#   Branch 5: pred=A, time=38.91s
#   Branch 6: pred=B, time=18.45s
#   Branch 7: pred=B, time=14.67s
#   Branch 8: pred=B, time=13.10s
#   Branch 9: pred=B, time=14.92s
#  gold=A preds=BBABBABBBB leader=B max=0.80 div=0.20 H=0.72 acc=0.20 class=lead80 time=271.8s
# Processing example index 56 (picked 56/100)...
#  Gold: C, Subject: Surgery, Question ID: a2c8fb9f-f775-4508-8e72-8ac484406ba6
#   Branch 0: pred=C, time=24.18s
#   Branch 1: pred=C, time=17.70s
#   Branch 2: pred=C, time=16.16s
#   Branch 3: pred=B, time=20.06s
#   Branch 4: pred=C, time=17.11s
#   Branch 5: pred=C, time=15.86s
#   Branch 6: pred=C, time=23.82s
#   Branch 7: pred=C, time=15.74s
#   Branch 8: pred=C, time=15.30s
#   Branch 9: pred=C, time=15.52s
#  gold=C preds=CCCBCCCCCC leader=C max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=181.5s
# Processing example index 57 (picked 57/100)...
# Processing example index 58 (picked 57/100)...
#  Gold: A, Subject: Biochemistry, Question ID: 89954831-6a35-49a3-811d-95cd7edc2c7c
#   Branch 0: pred=A, time=26.30s
#   Branch 1: pred=B, time=22.87s
#   Branch 2: pred=A, time=21.65s
#   Branch 3: pred=A, time=24.81s
#   Branch 4: pred=A, time=26.35s
#   Branch 5: pred=A, time=23.11s
#   Branch 6: pred=B, time=22.38s
#   Branch 7: pred=A, time=26.73s
#   Branch 8: pred=A, time=27.44s
#   Branch 9: pred=A, time=22.72s
#  gold=A preds=ABAAAABAAA leader=A max=0.80 div=0.20 H=0.72 acc=0.80 class=lead80 time=244.4s
# Processing example index 59 (picked 58/100)...
# Processing example index 60 (picked 58/100)...
# Processing example index 61 (picked 58/100)...
# Processing example index 62 (picked 58/100)...
#  Gold: D, Subject: Pathology, Question ID: b69ced59-82cc-43b7-b3b8-829f8ee8930b
#   Branch 0: pred=A, time=22.88s
#   Branch 1: pred=D, time=21.06s
#   Branch 2: pred=A, time=19.86s
#   Branch 3: pred=D, time=16.40s
#   Branch 4: pred=D, time=14.15s
#   Branch 5: pred=B, time=16.05s
#   Branch 6: pred=D, time=18.05s
#   Branch 7: pred=D, time=17.01s
#   Branch 8: pred=A, time=21.76s
#   Branch 9: pred=D, time=16.77s
#  gold=D preds=ADADDBDDAD leader=D max=0.60 div=0.40 H=1.30 acc=0.60 class=lead50 time=184.0s
# Processing example index 63 (picked 59/100)...
#  Gold: A, Subject: Pharmacology, Question ID: 65bef933-00cc-4f7b-8ca0-a77f2fe92c57
#   Branch 0: pred=A, time=16.56s
#   Branch 1: pred=A, time=17.45s
#   Branch 2: pred=C, time=15.66s
#   Branch 3: pred=C, time=18.52s
#   Branch 4: pred=B, time=13.99s
#   Branch 5: pred=A, time=15.05s
#   Branch 6: pred=A, time=14.33s
#   Branch 7: pred=A, time=18.22s
#   Branch 8: pred=C, time=18.12s
#   Branch 9: pred=A, time=14.77s
#  gold=A preds=AACCBAAACA leader=A max=0.60 div=0.40 H=1.30 acc=0.60 class=lead50 time=162.7s
# Processing example index 64 (picked 60/100)...
#  Gold: C, Subject: Pharmacology, Question ID: 16759fbf-ac94-4ec3-9fde-0702eee3eac5
#   Branch 0: pred=C, time=20.56s
#   Branch 1: pred=C, time=18.83s
#   Branch 2: pred=C, time=18.66s
#   Branch 3: pred=C, time=16.46s
#   Branch 4: pred=C, time=16.32s
#   Branch 5: pred=C, time=18.26s
#   Branch 6: pred=C, time=18.98s
#   Branch 7: pred=C, time=17.07s
#   Branch 8: pred=C, time=17.29s
#   Branch 9: pred=C, time=17.06s
#  gold=C preds=CCCCCCCCCC leader=C max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=179.5s
# Processing example index 65 (picked 61/100)...
#  Gold: D, Subject: Pediatrics, Question ID: 4032c899-2223-435f-a007-c513fd59a065
#   Branch 0: pred=D, time=28.89s
#   Branch 1: pred=D, time=26.73s
#   Branch 2: pred=D, time=27.04s
#   Branch 3: pred=D, time=29.65s
#   Branch 4: pred=D, time=30.89s
#   Branch 5: pred=D, time=35.43s
#   Branch 6: pred=D, time=31.62s
#   Branch 7: pred=A, time=29.51s
#   Branch 8: pred=D, time=33.17s
#   Branch 9: pred=D, time=30.64s
#  gold=D preds=DDDDDDDADD leader=D max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=303.6s
# Processing example index 66 (picked 62/100)...
#  Gold: A, Subject: Microbiology, Question ID: 9010a09d-b097-4371-afbc-c2532fe02740
#   Branch 0: pred=A, time=17.39s
#   Branch 1: pred=A, time=18.48s
#   Branch 2: pred=A, time=15.48s
#   Branch 3: pred=A, time=19.71s
#   Branch 4: pred=A, time=17.16s
#   Branch 5: pred=A, time=17.56s
#   Branch 6: pred=A, time=16.79s
#   Branch 7: pred=A, time=20.32s
#   Branch 8: pred=A, time=15.62s
#   Branch 9: pred=A, time=16.59s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=175.1s
# Processing example index 67 (picked 63/100)...
# Processing example index 68 (picked 63/100)...
# Processing example index 69 (picked 63/100)...
#  Gold: B, Subject: ENT, Question ID: 671eebea-f741-4ed8-bf68-36e36c8de1eb
#   Branch 0: pred=B, time=22.64s
#   Branch 1: pred=B, time=17.57s
#   Branch 2: pred=B, time=22.01s
#   Branch 3: pred=B, time=19.13s
#   Branch 4: pred=B, time=18.75s
#   Branch 5: pred=B, time=17.78s
#   Branch 6: pred=B, time=16.23s
#   Branch 7: pred=B, time=15.44s
#   Branch 8: pred=B, time=17.81s
#   Branch 9: pred=B, time=23.40s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=190.8s
# Processing example index 70 (picked 64/100)...
# Processing example index 71 (picked 64/100)...
#  Gold: D, Subject: Dental, Question ID: 3c053a67-9d94-4e22-b368-e7e3df80fcb9
#   Branch 0: pred=D, time=18.49s
#   Branch 1: pred=D, time=22.30s
#   Branch 2: pred=D, time=19.51s
#   Branch 3: pred=B, time=18.93s
#   Branch 4: pred=A, time=21.02s
#   Branch 5: pred=D, time=18.15s
#   Branch 6: pred=A, time=18.84s
#   Branch 7: pred=D, time=15.83s
#   Branch 8: pred=D, time=20.24s
#   Branch 9: pred=D, time=18.39s
#  gold=D preds=DDDBADADDD leader=D max=0.70 div=0.30 H=1.16 acc=0.70 class=lead50 time=191.7s
# Processing example index 72 (picked 65/100)...
#  Gold: B, Subject: Forensic Medicine, Question ID: 2ae293df-8147-46d5-bd46-b913a95c2593
#   Branch 0: pred=A, time=30.78s
#   Branch 1: pred=A, time=30.16s
#   Branch 2: pred=A, time=28.65s
#   Branch 3: pred=A, time=28.54s
#   Branch 4: pred=A, time=29.37s
#   Branch 5: pred=A, time=29.40s
#   Branch 6: pred=A, time=32.50s
#   Branch 7: pred=A, time=27.28s
#   Branch 8: pred=A, time=31.41s
#   Branch 9: pred=A, time=28.17s
#  gold=B preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=0.00 class=unanimous time=296.3s
# Processing example index 73 (picked 66/100)...
# Processing example index 74 (picked 66/100)...
# Processing example index 75 (picked 66/100)...
#  Gold: A, Subject: Microbiology, Question ID: 35fb00cb-9acc-4177-8873-c3915a142c99
#   Branch 0: pred=A, time=20.37s
#   Branch 1: pred=A, time=19.18s
#   Branch 2: pred=A, time=19.92s
#   Branch 3: pred=A, time=19.26s
#   Branch 4: pred=C, time=21.46s
#   Branch 5: pred=B, time=19.22s
#   Branch 6: pred=A, time=19.32s
#   Branch 7: pred=A, time=19.91s
#   Branch 8: pred=B, time=18.27s
#   Branch 9: pred=A, time=17.88s
#  gold=A preds=AAAACBAABA leader=A max=0.70 div=0.30 H=1.16 acc=0.70 class=lead50 time=194.8s
# Processing example index 76 (picked 67/100)...
# Processing example index 77 (picked 67/100)...
#  Gold: D, Subject: Medicine, Question ID: 234d826f-4a7b-4fd1-9799-b1a3602355fe
#   Branch 0: pred=D, time=32.31s
#   Branch 1: pred=D, time=32.80s
#   Branch 2: pred=D, time=25.69s
#   Branch 3: pred=D, time=23.28s
#   Branch 4: pred=D, time=27.41s
#   Branch 5: pred=D, time=23.57s
#   Branch 6: pred=A, time=25.25s
#   Branch 7: pred=D, time=25.97s
#   Branch 8: pred=None, time=27.74s
#   Branch 9: pred=A, time=28.24s
#  gold=D preds=DDDDDDAD_A leader=D max=0.78 div=0.22 H=0.76 acc=0.78 class=lead50 time=272.3s
# Processing example index 78 (picked 68/100)...
#  Gold: A, Subject: Medicine, Question ID: 6456df80-5db3-44f0-bc53-e3209b525d2f
#   Branch 0: pred=A, time=15.71s
#   Branch 1: pred=D, time=20.45s
#   Branch 2: pred=A, time=31.73s
#   Branch 3: pred=D, time=21.51s
#   Branch 4: pred=D, time=27.60s
#   Branch 5: pred=A, time=20.93s
#   Branch 6: pred=A, time=21.39s
#   Branch 7: pred=D, time=21.74s
#   Branch 8: pred=A, time=18.67s
#   Branch 9: pred=A, time=23.36s
#  gold=A preds=ADADDAADAA leader=A max=0.60 div=0.40 H=0.97 acc=0.60 class=lead50 time=223.1s
# Processing example index 79 (picked 69/100)...
#  Gold: D, Subject: Medicine, Question ID: edbdb125-7a27-4740-9e03-b379ae34773d
#   Branch 0: pred=D, time=19.39s
#   Branch 1: pred=A, time=15.78s
#   Branch 2: pred=C, time=19.83s
#   Branch 3: pred=D, time=16.68s
#   Branch 4: pred=D, time=16.51s
#   Branch 5: pred=D, time=19.05s
#   Branch 6: pred=D, time=15.69s
#   Branch 7: pred=D, time=15.73s
#   Branch 8: pred=D, time=20.66s
#   Branch 9: pred=D, time=20.48s
#  gold=D preds=DACDDDDDDD leader=D max=0.80 div=0.20 H=0.92 acc=0.80 class=lead80 time=179.8s
# Processing example index 80 (picked 70/100)...
#  Gold: D, Subject: Pathology, Question ID: 425262d7-1238-4195-a713-1cb8befefd2d
#   Branch 0: pred=D, time=18.98s
#   Branch 1: pred=D, time=16.30s
#   Branch 2: pred=D, time=15.56s
#   Branch 3: pred=D, time=18.35s
#   Branch 4: pred=D, time=19.76s
#   Branch 5: pred=D, time=19.89s
#   Branch 6: pred=D, time=22.64s
#   Branch 7: pred=D, time=20.82s
#   Branch 8: pred=D, time=20.52s
#   Branch 9: pred=D, time=22.19s
#  gold=D preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=195.0s
# Processing example index 81 (picked 71/100)...
#  Gold: B, Subject: Dental, Question ID: 3b514c9e-965c-463a-b141-9dcecd91c957
#   Branch 0: pred=B, time=12.29s
#   Branch 1: pred=B, time=12.23s
#   Branch 2: pred=C, time=12.87s
#   Branch 3: pred=C, time=14.19s
#   Branch 4: pred=B, time=12.49s
#   Branch 5: pred=B, time=14.01s
#   Branch 6: pred=B, time=13.40s
#   Branch 7: pred=B, time=14.72s
#   Branch 8: pred=B, time=14.16s
#   Branch 9: pred=A, time=17.70s
#  gold=B preds=BBCCBBBBBA leader=B max=0.70 div=0.30 H=1.16 acc=0.70 class=lead50 time=138.1s
# Processing example index 82 (picked 72/100)...
# Processing example index 83 (picked 72/100)...
#  Gold: C, Subject: Social & Preventive Medicine, Question ID: f5f3cd4b-3180-4f0e-b585-d681407b89d0
#   Branch 0: pred=C, time=17.69s
#   Branch 1: pred=A, time=49.44s
#   Branch 2: pred=A, time=45.58s
#   Branch 3: pred=A, time=49.52s
#   Branch 4: pred=C, time=21.45s
#   Branch 5: pred=C, time=18.28s
#   Branch 6: pred=C, time=23.16s
#   Branch 7: pred=A, time=49.80s
#   Branch 8: pred=D, time=45.57s
#   Branch 9: pred=C, time=21.24s
#  gold=C preds=CAAACCCADC leader=C max=0.50 div=0.50 H=1.36 acc=0.50 class=lead50 time=341.8s
# Processing example index 84 (picked 73/100)...
#  Gold: B, Subject: Biochemistry, Question ID: 3f95d1b3-f038-4875-993a-4e9afde8bd62
#   Branch 0: pred=A, time=21.23s
#   Branch 1: pred=B, time=17.70s
#   Branch 2: pred=B, time=12.73s
#   Branch 3: pred=A, time=16.90s
#   Branch 4: pred=B, time=18.06s
#   Branch 5: pred=B, time=21.55s
#   Branch 6: pred=B, time=16.63s
#   Branch 7: pred=B, time=19.93s
#   Branch 8: pred=B, time=17.49s
#   Branch 9: pred=D, time=16.64s
#  gold=B preds=ABBABBBBBD leader=B max=0.70 div=0.30 H=1.16 acc=0.70 class=lead50 time=178.9s
# Processing example index 85 (picked 74/100)...
#  Gold: A, Subject: Biochemistry, Question ID: 2be4ec28-ff65-4ba0-9a8f-346a819c99f1
#   Branch 0: pred=A, time=25.02s
#   Branch 1: pred=A, time=27.11s
#   Branch 2: pred=A, time=22.74s
#   Branch 3: pred=A, time=23.79s
#   Branch 4: pred=A, time=22.83s
#   Branch 5: pred=A, time=24.87s
#   Branch 6: pred=A, time=24.67s
#   Branch 7: pred=A, time=21.37s
#   Branch 8: pred=A, time=21.95s
#   Branch 9: pred=A, time=21.16s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=235.6s
# Processing example index 86 (picked 75/100)...
#  Gold: B, Subject: Social & Preventive Medicine, Question ID: f8c7a8c6-351b-4ffe-b108-dc3363837624
#   Branch 0: pred=D, time=28.69s
#   Branch 1: pred=D, time=38.96s
#   Branch 2: pred=D, time=38.70s
#   Branch 3: pred=A, time=37.59s
#   Branch 4: pred=A, time=22.73s
#   Branch 5: pred=B, time=16.82s
#   Branch 6: pred=A, time=22.57s
#   Branch 7: pred=A, time=23.58s
#   Branch 8: pred=A, time=22.94s
#   Branch 9: pred=D, time=40.70s
#  gold=B preds=DDDAABAAAD leader=A max=0.50 div=0.50 H=1.36 acc=0.10 class=lead50 time=293.3s
# Processing example index 87 (picked 76/100)...
# Processing example index 88 (picked 76/100)...
#  Gold: A, Subject: Social & Preventive Medicine, Question ID: 78cde0de-1205-4bcb-a646-992a909fd268
#   Branch 0: pred=A, time=12.32s
#   Branch 1: pred=A, time=12.27s
#   Branch 2: pred=A, time=12.92s
#   Branch 3: pred=A, time=10.64s
#   Branch 4: pred=A, time=13.93s
#   Branch 5: pred=A, time=12.11s
#   Branch 6: pred=A, time=12.57s
#   Branch 7: pred=A, time=12.13s
#   Branch 8: pred=A, time=11.76s
#   Branch 9: pred=A, time=12.48s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=123.2s
# Processing example index 89 (picked 77/100)...
#  Gold: B, Subject: Forensic Medicine, Question ID: 044e8f11-ca21-4220-9ddc-0fca648ed401
#   Branch 0: pred=B, time=25.60s
#   Branch 1: pred=B, time=32.93s
#   Branch 2: pred=B, time=22.74s
#   Branch 3: pred=B, time=15.18s
#   Branch 4: pred=B, time=14.76s
#   Branch 5: pred=B, time=18.67s
#   Branch 6: pred=B, time=21.85s
#   Branch 7: pred=B, time=18.04s
#   Branch 8: pred=B, time=13.56s
#   Branch 9: pred=B, time=16.01s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=199.4s
# Processing example index 90 (picked 78/100)...
# Processing example index 91 (picked 78/100)...
# Processing example index 92 (picked 78/100)...
# Processing example index 93 (picked 78/100)...
# Processing example index 94 (picked 78/100)...
#  Gold: A, Subject: Anaesthesia, Question ID: bee22c8c-3527-403f-903a-bd535bc3dd68
#   Branch 0: pred=C, time=25.21s
#   Branch 1: pred=C, time=17.40s
#   Branch 2: pred=D, time=20.24s
#   Branch 3: pred=C, time=22.10s
#   Branch 4: pred=D, time=25.99s
#   Branch 5: pred=C, time=19.47s
#   Branch 6: pred=D, time=24.84s
#   Branch 7: pred=C, time=18.36s
#   Branch 8: pred=D, time=23.98s
#   Branch 9: pred=C, time=20.56s
#  gold=A preds=CCDCDCDCDC leader=C max=0.60 div=0.40 H=0.97 acc=0.00 class=lead50 time=218.2s
# Processing example index 95 (picked 79/100)...
#  Gold: D, Subject: Biochemistry, Question ID: 00b68a41-476c-4506-9961-35e03dd44243
#   Branch 0: pred=D, time=24.42s
#   Branch 1: pred=D, time=19.29s
#   Branch 2: pred=A, time=23.56s
#   Branch 3: pred=D, time=22.66s
#   Branch 4: pred=D, time=18.56s
#   Branch 5: pred=D, time=20.93s
#   Branch 6: pred=A, time=22.15s
#   Branch 7: pred=D, time=28.70s
#   Branch 8: pred=D, time=24.27s
#   Branch 9: pred=D, time=20.67s
#  gold=D preds=DDADDDADDD leader=D max=0.80 div=0.20 H=0.72 acc=0.80 class=lead80 time=225.2s
# Processing example index 96 (picked 80/100)...
# Processing example index 97 (picked 80/100)...
# Processing example index 98 (picked 80/100)...
#  Gold: B, Subject: Social & Preventive Medicine, Question ID: f8a5b0e2-b529-4ad4-b55d-f6e5fc4708e1
#   Branch 0: pred=B, time=15.04s
#   Branch 1: pred=B, time=15.53s
#   Branch 2: pred=B, time=15.22s
#   Branch 3: pred=B, time=24.83s
#   Branch 4: pred=B, time=15.50s
#   Branch 5: pred=B, time=20.01s
#   Branch 6: pred=B, time=15.20s
#   Branch 7: pred=B, time=19.28s
#   Branch 8: pred=B, time=16.48s
#   Branch 9: pred=B, time=23.23s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=180.4s
# Processing example index 99 (picked 81/100)...
#  Gold: B, Subject: Physiology, Question ID: d947e9b8-6731-4b40-bbf5-9417c24dda50
#   Branch 0: pred=B, time=21.56s
#   Branch 1: pred=B, time=21.85s
#   Branch 2: pred=B, time=19.50s
#   Branch 3: pred=B, time=14.84s
#   Branch 4: pred=B, time=18.89s
#   Branch 5: pred=B, time=19.80s
#   Branch 6: pred=B, time=22.22s
#   Branch 7: pred=B, time=18.31s
#   Branch 8: pred=B, time=18.04s
#   Branch 9: pred=B, time=22.16s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=197.2s
# Processing example index 100 (picked 82/100)...
# Processing example index 101 (picked 82/100)...
# Processing example index 102 (picked 82/100)...
#  Gold: C, Subject: Physiology, Question ID: b8a31186-4e61-46f8-bf04-c3e22f907418
#   Branch 0: pred=B, time=36.72s
#   Branch 1: pred=A, time=28.59s
#   Branch 2: pred=B, time=42.72s
#   Branch 3: pred=A, time=49.71s
#   Branch 4: pred=B, time=34.36s
#   Branch 5: pred=B, time=23.82s
#   Branch 6: pred=A, time=49.69s
#   Branch 7: pred=B, time=42.56s
#   Branch 8: pred=A, time=49.48s
#   Branch 9: pred=B, time=41.93s
#  gold=C preds=BABABBABAB leader=B max=0.60 div=0.40 H=0.97 acc=0.00 class=lead50 time=399.6s
# Processing example index 103 (picked 83/100)...
#  Gold: A, Subject: Physiology, Question ID: 4a5c465a-979c-468e-a5c8-286d987f9d4d
#   Branch 0: pred=A, time=19.65s
#   Branch 1: pred=A, time=18.95s
#   Branch 2: pred=A, time=35.10s
#   Branch 3: pred=A, time=47.61s
#   Branch 4: pred=A, time=15.33s
#   Branch 5: pred=A, time=19.09s
#   Branch 6: pred=A, time=23.74s
#   Branch 7: pred=A, time=19.59s
#   Branch 8: pred=A, time=23.89s
#   Branch 9: pred=A, time=17.49s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=240.5s
# Processing example index 104 (picked 84/100)...
# Processing example index 105 (picked 84/100)...
#  Gold: A, Subject: Radiology, Question ID: 477dea37-f0b6-4a6d-b77a-766ded28f2b6
#   Branch 0: pred=A, time=21.49s
#   Branch 1: pred=A, time=23.20s
#   Branch 2: pred=A, time=23.00s
#   Branch 3: pred=A, time=21.87s
#   Branch 4: pred=A, time=19.59s
#   Branch 5: pred=A, time=25.93s
#   Branch 6: pred=A, time=22.85s
#   Branch 7: pred=A, time=20.96s
#   Branch 8: pred=A, time=22.81s
#   Branch 9: pred=A, time=24.99s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=226.7s
# Processing example index 106 (picked 85/100)...
# Processing example index 107 (picked 85/100)...
# Processing example index 108 (picked 85/100)...
# Processing example index 109 (picked 85/100)...
#  Gold: B, Subject: Pediatrics, Question ID: 56a4d5b8-c2e7-4534-9511-a30ff0769814
#   Branch 0: pred=B, time=14.96s
#   Branch 1: pred=B, time=17.89s
#   Branch 2: pred=B, time=15.40s
#   Branch 3: pred=B, time=23.95s
#   Branch 4: pred=B, time=17.70s
#   Branch 5: pred=B, time=16.70s
#   Branch 6: pred=B, time=18.06s
#   Branch 7: pred=B, time=17.33s
#   Branch 8: pred=B, time=18.28s
#   Branch 9: pred=D, time=18.65s
#  gold=B preds=BBBBBBBBBD leader=B max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=179.0s
# Processing example index 110 (picked 86/100)...
# Processing example index 111 (picked 86/100)...
#  Gold: A, Subject: Pediatrics, Question ID: 16533187-64d0-47f9-be71-dba4d56615fe
#   Branch 0: pred=A, time=23.12s
#   Branch 1: pred=A, time=27.72s
#   Branch 2: pred=D, time=25.75s
#   Branch 3: pred=A, time=24.97s
#   Branch 4: pred=A, time=29.54s
#   Branch 5: pred=A, time=28.31s
#   Branch 6: pred=A, time=24.96s
#   Branch 7: pred=A, time=23.29s
#   Branch 8: pred=A, time=30.04s
#   Branch 9: pred=A, time=24.96s
#  gold=A preds=AADAAAAAAA leader=A max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=262.7s
# Processing example index 112 (picked 87/100)...
# Processing example index 113 (picked 87/100)...
# Processing example index 114 (picked 87/100)...
# Processing example index 115 (picked 87/100)...
#  Gold: D, Subject: Microbiology, Question ID: a1bea2c7-217e-4240-a208-541618437eec
#   Branch 0: pred=C, time=20.95s
#   Branch 1: pred=C, time=21.69s
#   Branch 2: pred=C, time=17.35s
#   Branch 3: pred=D, time=23.85s
#   Branch 4: pred=C, time=21.76s
#   Branch 5: pred=C, time=21.77s
#   Branch 6: pred=D, time=20.91s
#   Branch 7: pred=C, time=22.21s
#   Branch 8: pred=C, time=20.51s
#   Branch 9: pred=C, time=29.00s
#  gold=D preds=CCCDCCDCCC leader=C max=0.80 div=0.20 H=0.72 acc=0.20 class=lead80 time=220.0s
# Processing example index 116 (picked 88/100)...
# Processing example index 117 (picked 88/100)...
# Processing example index 118 (picked 88/100)...
# Processing example index 119 (picked 88/100)...
# Processing example index 120 (picked 88/100)...
# Processing example index 121 (picked 88/100)...
# Processing example index 122 (picked 88/100)...
# Processing example index 123 (picked 88/100)...
#  Gold: A, Subject: Forensic Medicine, Question ID: 34d20a1d-da67-4205-b8c7-981dc313289f
#   Branch 0: pred=A, time=13.83s
#   Branch 1: pred=A, time=14.40s
#   Branch 2: pred=A, time=13.14s
#   Branch 3: pred=A, time=16.00s
#   Branch 4: pred=B, time=15.49s
#   Branch 5: pred=A, time=16.46s
#   Branch 6: pred=A, time=15.38s
#   Branch 7: pred=A, time=17.47s
#   Branch 8: pred=B, time=18.30s
#   Branch 9: pred=B, time=25.29s
#  gold=A preds=AAAABAAABB leader=A max=0.70 div=0.30 H=0.88 acc=0.70 class=lead50 time=165.8s
# Processing example index 124 (picked 89/100)...
# Processing example index 125 (picked 89/100)...
# Processing example index 126 (picked 89/100)...
# Processing example index 127 (picked 89/100)...
# Processing example index 128 (picked 89/100)...
# Processing example index 129 (picked 89/100)...
# Processing example index 130 (picked 89/100)...
# Processing example index 131 (picked 89/100)...
#  Gold: B, Subject: Microbiology, Question ID: ced0e6e7-048a-467e-aa7e-e10def9ebb5e
#   Branch 0: pred=D, time=20.48s
#   Branch 1: pred=D, time=19.36s
#   Branch 2: pred=D, time=17.69s
#   Branch 3: pred=D, time=19.97s
#   Branch 4: pred=D, time=18.58s
#   Branch 5: pred=D, time=19.60s
#   Branch 6: pred=D, time=20.20s
#   Branch 7: pred=D, time=21.06s
#   Branch 8: pred=D, time=20.50s
#   Branch 9: pred=D, time=18.49s
#  gold=B preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=0.00 class=unanimous time=196.0s
# Processing example index 132 (picked 90/100)...
# Processing example index 133 (picked 90/100)...
#  Gold: D, Subject: Ophthalmology, Question ID: 1e8c037d-b7d9-48c9-8aba-39b01a178619
#   Branch 0: pred=D, time=17.79s
#   Branch 1: pred=D, time=17.70s
#   Branch 2: pred=D, time=19.44s
#   Branch 3: pred=D, time=20.73s
#   Branch 4: pred=D, time=17.85s
#   Branch 5: pred=D, time=17.61s
#   Branch 6: pred=D, time=18.17s
#   Branch 7: pred=D, time=20.52s
#   Branch 8: pred=D, time=19.02s
#   Branch 9: pred=D, time=18.80s
#  gold=D preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=187.7s
# Processing example index 134 (picked 91/100)...
# Processing example index 135 (picked 91/100)...
# Processing example index 136 (picked 91/100)...
#  Gold: A, Subject: Forensic Medicine, Question ID: 27eecec7-69c5-40bd-9d90-c19e43acc9a3
#   Branch 0: pred=B, time=26.09s
#   Branch 1: pred=B, time=22.23s
#   Branch 2: pred=B, time=22.24s
#   Branch 3: pred=B, time=27.41s
#   Branch 4: pred=B, time=21.84s
#   Branch 5: pred=B, time=22.14s
#   Branch 6: pred=B, time=26.52s
#   Branch 7: pred=B, time=23.43s
#   Branch 8: pred=B, time=28.63s
#   Branch 9: pred=B, time=24.65s
#  gold=A preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=0.00 class=unanimous time=245.2s
# Processing example index 137 (picked 92/100)...
# Processing example index 138 (picked 92/100)...
# Processing example index 139 (picked 92/100)...
#  Gold: D, Subject: Microbiology, Question ID: 3d3896ce-b736-4e9a-bb7e-cb4608cdd29a
#   Branch 0: pred=D, time=18.23s
#   Branch 1: pred=D, time=19.62s
#   Branch 2: pred=D, time=18.48s
#   Branch 3: pred=D, time=20.60s
#   Branch 4: pred=D, time=21.01s
#   Branch 5: pred=D, time=18.17s
#   Branch 6: pred=D, time=21.50s
#   Branch 7: pred=D, time=21.30s
#   Branch 8: pred=D, time=22.75s
#   Branch 9: pred=D, time=17.44s
#  gold=D preds=DDDDDDDDDD leader=D max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=199.1s
# Processing example index 140 (picked 93/100)...
#  Gold: B, Subject: Anaesthesia, Question ID: 820b79a8-3eef-494b-a007-995db6b5258c
#   Branch 0: pred=D, time=18.73s
#   Branch 1: pred=D, time=19.36s
#   Branch 2: pred=C, time=18.04s
#   Branch 3: pred=D, time=19.85s
#   Branch 4: pred=D, time=21.42s
#   Branch 5: pred=D, time=16.51s
#   Branch 6: pred=D, time=15.95s
#   Branch 7: pred=D, time=20.14s
#   Branch 8: pred=D, time=20.29s
#   Branch 9: pred=D, time=19.64s
#  gold=B preds=DDCDDDDDDD leader=D max=0.90 div=0.10 H=0.47 acc=0.00 class=lead80 time=190.0s
# Processing example index 141 (picked 94/100)...
# Processing example index 142 (picked 94/100)...
# Processing example index 143 (picked 94/100)...
# Processing example index 144 (picked 94/100)...
# Processing example index 145 (picked 94/100)...
# Processing example index 146 (picked 94/100)...
# Processing example index 147 (picked 94/100)...
# Processing example index 148 (picked 94/100)...
# Processing example index 149 (picked 94/100)...
#  Gold: A, Subject: ENT, Question ID: 16ce8442-864b-43f1-b815-f9096e55fa54
#   Branch 0: pred=A, time=16.40s
#   Branch 1: pred=A, time=12.32s
#   Branch 2: pred=A, time=16.15s
#   Branch 3: pred=A, time=17.02s
#   Branch 4: pred=A, time=13.79s
#   Branch 5: pred=A, time=18.97s
#   Branch 6: pred=B, time=15.96s
#   Branch 7: pred=A, time=14.47s
#   Branch 8: pred=A, time=16.26s
#   Branch 9: pred=A, time=12.66s
#  gold=A preds=AAAAAABAAA leader=A max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=154.0s
# Processing example index 150 (picked 95/100)...
# Processing example index 151 (picked 95/100)...
#  Gold: D, Subject: Ophthalmology, Question ID: 796d7b5d-f79d-4c6a-860c-198e9404ea07
#   Branch 0: pred=A, time=14.05s
#   Branch 1: pred=A, time=21.23s
#   Branch 2: pred=D, time=13.82s
#   Branch 3: pred=A, time=17.37s
#   Branch 4: pred=A, time=16.97s
#   Branch 5: pred=A, time=24.29s
#   Branch 6: pred=A, time=23.66s
#   Branch 7: pred=A, time=22.25s
#   Branch 8: pred=A, time=17.57s
#   Branch 9: pred=D, time=13.63s
#  gold=D preds=AADAAAAAAD leader=A max=0.80 div=0.20 H=0.72 acc=0.20 class=lead80 time=184.9s
# Processing example index 152 (picked 96/100)...
# Processing example index 153 (picked 96/100)...
# Processing example index 154 (picked 96/100)...
#  Gold: B, Subject: Pediatrics, Question ID: 761c3922-2330-4ccc-9fc2-64911995760b
#   Branch 0: pred=B, time=16.21s
#   Branch 1: pred=B, time=14.72s
#   Branch 2: pred=B, time=16.41s
#   Branch 3: pred=B, time=14.45s
#   Branch 4: pred=B, time=17.57s
#   Branch 5: pred=B, time=14.74s
#   Branch 6: pred=B, time=15.13s
#   Branch 7: pred=B, time=14.67s
#   Branch 8: pred=B, time=15.97s
#   Branch 9: pred=B, time=16.54s
#  gold=B preds=BBBBBBBBBB leader=B max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=156.5s
# Processing example index 155 (picked 97/100)...
# Processing example index 156 (picked 97/100)...
# Processing example index 157 (picked 97/100)...
#  Gold: D, Subject: Skin, Question ID: 26124571-60c3-4509-9c33-981bc3b40054
#   Branch 0: pred=C, time=17.79s
#   Branch 1: pred=D, time=14.86s
#   Branch 2: pred=D, time=14.35s
#   Branch 3: pred=D, time=17.82s
#   Branch 4: pred=D, time=15.96s
#   Branch 5: pred=D, time=16.64s
#   Branch 6: pred=D, time=14.52s
#   Branch 7: pred=D, time=15.50s
#   Branch 8: pred=D, time=12.92s
#   Branch 9: pred=D, time=16.18s
#  gold=D preds=CDDDDDDDDD leader=D max=0.90 div=0.10 H=0.47 acc=0.90 class=lead80 time=156.6s
# Processing example index 158 (picked 98/100)...
# Processing example index 159 (picked 98/100)...
# Processing example index 160 (picked 98/100)...
# Processing example index 161 (picked 98/100)...
# Processing example index 162 (picked 98/100)...
# Processing example index 163 (picked 98/100)...
# Processing example index 164 (picked 98/100)...
# Processing example index 165 (picked 98/100)...
#  Gold: D, Subject: Biochemistry, Question ID: 0ae79405-095f-47c3-8fa6-e61495e66324
#   Branch 0: pred=A, time=19.55s
#   Branch 1: pred=D, time=22.09s
#   Branch 2: pred=D, time=19.52s
#   Branch 3: pred=D, time=19.26s
#   Branch 4: pred=D, time=20.66s
#   Branch 5: pred=D, time=23.48s
#   Branch 6: pred=D, time=20.05s
#   Branch 7: pred=D, time=19.06s
#   Branch 8: pred=A, time=24.15s
#   Branch 9: pred=D, time=17.01s
#  gold=D preds=ADDDDDDDAD leader=D max=0.80 div=0.20 H=0.72 acc=0.80 class=lead80 time=204.9s
# Processing example index 166 (picked 99/100)...
# Processing example index 167 (picked 99/100)...
# Processing example index 168 (picked 99/100)...
# Processing example index 169 (picked 99/100)...
# Processing example index 170 (picked 99/100)...
# Processing example index 171 (picked 99/100)...
#  Gold: A, Subject: Microbiology, Question ID: 081dedb5-37f1-482c-a416-599ac0ab619a
#   Branch 0: pred=A, time=20.47s
#   Branch 1: pred=A, time=16.76s
#   Branch 2: pred=A, time=22.12s
#   Branch 3: pred=A, time=19.40s
#   Branch 4: pred=A, time=19.80s
#   Branch 5: pred=A, time=16.68s
#   Branch 6: pred=A, time=20.84s
#   Branch 7: pred=A, time=18.10s
#   Branch 8: pred=A, time=19.74s
#   Branch 9: pred=A, time=21.41s
#  gold=A preds=AAAAAAAAAA leader=A max=1.00 div=0.00 H=-0.00 acc=1.00 class=unanimous time=195.4s
#
# Inference loop completed.
# Wrote 100 full records to: medmcqa_branches_full_N100_seed42_maxnew1024_b10_t0.8.jsonl
# Wrote 100 summary records to: medmcqa_branches_summary_N100_seed42_maxnew1024_b10_t0.8.jsonl
# Total wall time: 21468.5s
#
# Final bucket counts:
#   unanimous_correct : 32
#   unanimous_wrong   : 6
#   lead80_correct    : 23
#   lead80_wrong      : 10
#   lead50_correct    : 14
#   lead50_wrong      : 12
#   no_leader         : 3
#   invalid_all_none  : 0
#
# Subjects sampled (top 10):
#   Pediatrics: 7
#   Pharmacology: 7
#   Microbiology: 7
#   Pathology: 7
#   Anatomy: 7
#   Surgery: 7
#   Social & Preventive Medicine: 7
#   Dental: 7
#   Gynaecology & Obstetrics: 7
#   Medicine: 7
