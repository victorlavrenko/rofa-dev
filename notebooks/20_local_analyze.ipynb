# %% [markdown]
# # ROFA Local Analysis
#
# Load existing logs and run `scripts/analyze.py`.

# %%
# %pip install -q datasets

# %%
# !python scripts/analyze.py --summary /path/to/run/summary.jsonl
